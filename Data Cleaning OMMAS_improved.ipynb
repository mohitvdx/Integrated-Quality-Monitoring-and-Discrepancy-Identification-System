# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Nitin Yadav\\Downloads\\NQM_SQM_Mon_Works_Detail_Report (3).csv",skiprows=3)

# %%
df
# Out:
#      Textbox39 Textbox37 Textbox35      Textbox33    Textbox31  Textbox11  \
# 0       Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 1       Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 2       Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 3       Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 4       Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# ...        ...       ...       ...            ...          ...        ...
# 7217    Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 7218    Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 7219    Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 7220    Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 7221    Sr.No.  District     Block  Sanction Year  Package No.  Road Name
#
#         Textbox15              Textbox17     Textbox13              Textbox19  \
# 0     Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 1     Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 2     Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 3     Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 4     Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# ...           ...                    ...           ...                    ...
# 7217  Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 7218  Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 7219  Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 7220  Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 7221  Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
#
#       ...                                      IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ...  ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     ...  MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2     ...  MRL25-Raibha to Kirawali Achhnera Road via Dha...            5.00
# 3     ...        MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 4     ...                        T01-Achhrena to Kitham Road           12.00
# ...   ...                                                ...             ...
# 7217  ...         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7218  ...         SH-98 - Jogiyapur- Beerapur- Jogapur road             3.25
# 7219  ...                              SH-98 - Shirhira road            2.80
# 7220  ...                      Bhaupur- Kalikadham  - Tendui            2.95
# 7221  ...                 MRL15-karehane tikara to khalispur            5.00
#
#      NQM_INSP_COUNT             NQM_GRADE SQM_INSP_COUNT1       SQM_GRADE  \
# 0                 2          Satisfactory               8    Satisfactory
# 1                 1          Satisfactory               7    Satisfactory
# 2                 1        Unsatisfactory               5    Satisfactory
# 3                 1          Satisfactory               4    Satisfactory
# 4                 0                    --               2    Satisfactory
# ...             ...                   ...             ...             ...
# 7217              0                    --               1    Satisfactory
# 7218              1        Unsatisfactory               5    Satisfactory
# 7219              1        Unsatisfactory               4    Satisfactory
# 7220              0                    --               3  Unsatisfactory
# 7221              1  Required Improvement               5    Satisfactory
#
#      Textbox67   Textbox72  Textbox73 Textbox74
# 0        Total  43,170.314      4,824    31,426
# 1        Total  43,170.314      4,824    31,426
# 2        Total  43,170.314      4,824    31,426
# 3        Total  43,170.314      4,824    31,426
# 4        Total  43,170.314      4,824    31,426
# ...        ...         ...        ...       ...
# 7217     Total  43,170.314      4,824    31,426
# 7218     Total  43,170.314      4,824    31,426
# 7219     Total  43,170.314      4,824    31,426
# 7220     Total  43,170.314      4,824    31,426
# 7221     Total  43,170.314      4,824    31,426
#
# [7222 rows x 26 columns]

# %%
df1 = df.drop(['Textbox39','Textbox37','Textbox35','Textbox33','Textbox31','Textbox11','Textbox15','Textbox17','Textbox13','Textbox19','Textbox21','Textbox40','Textbox67','Textbox72','Textbox73','Textbox74'], axis='columns')

# %%
df1
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0             Agra   Achhnera     2016-2017         UP0177
# 1             Agra   Achhnera     2018-2019         UP0185
# 2             Agra   Achhnera     2021-2022        UP01103
# 3             Agra   Achhnera     2021-2022        UP01115
# 4             Agra   Achhnera     2021-2022         UP0188
# ...            ...        ...           ...            ...
# 7217      Varanasi   Sewapuri     2007-2008         UP7041
# 7218      Varanasi   Sewapuri     2012-2013         UP7043
# 7219      Varanasi   Sewapuri     2012-2013         UP7043
# 7220      Varanasi   Sewapuri     2012-2013         UP7049
# 7221      Varanasi   Sewapuri     2020-2021         UP7090
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2     MRL25-Raibha to Kirawali Achhnera Road via Dha...            5.00
# 3           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 4                           T01-Achhrena to Kitham Road           12.00
# ...                                                 ...             ...
# 7217         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7218         SH-98 - Jogiyapur- Beerapur- Jogapur road             3.25
# 7219                              SH-98 - Shirhira road            2.80
# 7220                      Bhaupur- Kalikadham  - Tendui            2.95
# 7221                 MRL15-karehane tikara to khalispur            5.00
#
#       NQM_INSP_COUNT             NQM_GRADE  SQM_INSP_COUNT1       SQM_GRADE
# 0                  2          Satisfactory                8    Satisfactory
# 1                  1          Satisfactory                7    Satisfactory
# 2                  1        Unsatisfactory                5    Satisfactory
# 3                  1          Satisfactory                4    Satisfactory
# 4                  0                    --                2    Satisfactory
# ...              ...                   ...              ...             ...
# 7217               0                    --                1    Satisfactory
# 7218               1        Unsatisfactory                5    Satisfactory
# 7219               1        Unsatisfactory                4    Satisfactory
# 7220               0                    --                3  Unsatisfactory
# 7221               1  Required Improvement                5    Satisfactory
#
# [7222 rows x 10 columns]

# %%
df1['SQM_INSP_COUNT1'].max()
# Out:
# 14

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1.describe()
# Out:
#        IMS_PAV_LENGTH  NQM_INSP_COUNT  SQM_INSP_COUNT1
# count     7222.000000     7222.000000      7222.000000
# mean         5.977612        0.667959         4.351426
# std          3.986371        0.724066         2.619637
# min          0.000000        0.000000         0.000000
# 25%          2.500000        0.000000         2.000000
# 50%          5.745000        1.000000         4.000000
# 75%          8.000000        1.000000         6.000000
# max         61.500000        5.000000        14.000000

# %%
df1.corr()
# Out:
# C:\Users\Nitin Yadav\AppData\Local\Temp\ipykernel_27724\473017434.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.corr()
#                  IMS_PAV_LENGTH  NQM_INSP_COUNT  SQM_INSP_COUNT1
# IMS_PAV_LENGTH         1.000000        0.156549         0.235085
# NQM_INSP_COUNT         0.156549        1.000000         0.327138
# SQM_INSP_COUNT1        0.235085        0.327138         1.000000

# %%
df1['NQM_GRADE'].replace('--', 'Uninspected', inplace=True)
df1['SQM_GRADE'].replace('--', 'Uninspected', inplace=True)

# %%
df1
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0             Agra   Achhnera     2016-2017         UP0177
# 1             Agra   Achhnera     2018-2019         UP0185
# 2             Agra   Achhnera     2021-2022        UP01103
# 3             Agra   Achhnera     2021-2022        UP01115
# 4             Agra   Achhnera     2021-2022         UP0188
# ...            ...        ...           ...            ...
# 7217      Varanasi   Sewapuri     2007-2008         UP7041
# 7218      Varanasi   Sewapuri     2012-2013         UP7043
# 7219      Varanasi   Sewapuri     2012-2013         UP7043
# 7220      Varanasi   Sewapuri     2012-2013         UP7049
# 7221      Varanasi   Sewapuri     2020-2021         UP7090
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2     MRL25-Raibha to Kirawali Achhnera Road via Dha...            5.00
# 3           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 4                           T01-Achhrena to Kitham Road           12.00
# ...                                                 ...             ...
# 7217         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7218         SH-98 - Jogiyapur- Beerapur- Jogapur road             3.25
# 7219                              SH-98 - Shirhira road            2.80
# 7220                      Bhaupur- Kalikadham  - Tendui            2.95
# 7221                 MRL15-karehane tikara to khalispur            5.00
#
#       NQM_INSP_COUNT             NQM_GRADE  SQM_INSP_COUNT1       SQM_GRADE
# 0                  2          Satisfactory                8    Satisfactory
# 1                  1          Satisfactory                7    Satisfactory
# 2                  1        Unsatisfactory                5    Satisfactory
# 3                  1          Satisfactory                4    Satisfactory
# 4                  0           Uninspected                2    Satisfactory
# ...              ...                   ...              ...             ...
# 7217               0           Uninspected                1    Satisfactory
# 7218               1        Unsatisfactory                5    Satisfactory
# 7219               1        Unsatisfactory                4    Satisfactory
# 7220               0           Uninspected                3  Unsatisfactory
# 7221               1  Required Improvement                5    Satisfactory
#
# [7222 rows x 10 columns]

# %%
plt.figure(figsize=(7,4))
sns.countplot(data=df1,x='NQM_GRADE')
# Out:
# <Axes: xlabel='NQM_GRADE', ylabel='count'>

# %%
plt.figure(figsize=(7,4))
sns.countplot(data=df1,x='SQM_GRADE')
# Out:
# <Axes: xlabel='SQM_GRADE', ylabel='count'>

# %%
df1['SQM_GRADE'].replace('Satisfactory', 1, inplace=True)
df1['SQM_GRADE'].replace('Unsatisfactory', 0, inplace=True)
df1['SQM_GRADE'].replace('Required Improvement', 2, inplace=True)
df1['SQM_GRADE'].replace('Uninspected', 3, inplace=True)

# %%
df1['NQM_GRADE'].replace('Satisfactory', 1, inplace=True)
df1['NQM_GRADE'].replace('Unsatisfactory', 0, inplace=True)
df1['NQM_GRADE'].replace('Required Improvement', 2, inplace=True)
df1['NQM_GRADE'].replace('Uninspected', 3, inplace=True)

# %%
df1
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0             Agra   Achhnera     2016-2017         UP0177
# 1             Agra   Achhnera     2018-2019         UP0185
# 2             Agra   Achhnera     2021-2022        UP01103
# 3             Agra   Achhnera     2021-2022        UP01115
# 4             Agra   Achhnera     2021-2022         UP0188
# ...            ...        ...           ...            ...
# 7217      Varanasi   Sewapuri     2007-2008         UP7041
# 7218      Varanasi   Sewapuri     2012-2013         UP7043
# 7219      Varanasi   Sewapuri     2012-2013         UP7043
# 7220      Varanasi   Sewapuri     2012-2013         UP7049
# 7221      Varanasi   Sewapuri     2020-2021         UP7090
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2     MRL25-Raibha to Kirawali Achhnera Road via Dha...            5.00
# 3           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 4                           T01-Achhrena to Kitham Road           12.00
# ...                                                 ...             ...
# 7217         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7218         SH-98 - Jogiyapur- Beerapur- Jogapur road             3.25
# 7219                              SH-98 - Shirhira road            2.80
# 7220                      Bhaupur- Kalikadham  - Tendui            2.95
# 7221                 MRL15-karehane tikara to khalispur            5.00
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE
# 0                  2          1                8          1
# 1                  1          1                7          1
# 2                  1          0                5          1
# 3                  1          1                4          1
# 4                  0          3                2          1
# ...              ...        ...              ...        ...
# 7217               0          3                1          1
# 7218               1          0                5          1
# 7219               1          0                4          1
# 7220               0          3                3          0
# 7221               1          2                5          1
#
# [7222 rows x 10 columns]

# %%
df1['DISCREPANCY'] = np.where((df1['NQM_GRADE'] == df1['SQM_GRADE'])|(df1['NQM_GRADE']==3)|(df1['SQM_GRADE']==3),0, 1)

# %%
df1
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0             Agra   Achhnera     2016-2017         UP0177
# 1             Agra   Achhnera     2018-2019         UP0185
# 2             Agra   Achhnera     2021-2022        UP01103
# 3             Agra   Achhnera     2021-2022        UP01115
# 4             Agra   Achhnera     2021-2022         UP0188
# ...            ...        ...           ...            ...
# 7217      Varanasi   Sewapuri     2007-2008         UP7041
# 7218      Varanasi   Sewapuri     2012-2013         UP7043
# 7219      Varanasi   Sewapuri     2012-2013         UP7043
# 7220      Varanasi   Sewapuri     2012-2013         UP7049
# 7221      Varanasi   Sewapuri     2020-2021         UP7090
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2     MRL25-Raibha to Kirawali Achhnera Road via Dha...            5.00
# 3           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 4                           T01-Achhrena to Kitham Road           12.00
# ...                                                 ...             ...
# 7217         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7218         SH-98 - Jogiyapur- Beerapur- Jogapur road             3.25
# 7219                              SH-98 - Shirhira road            2.80
# 7220                      Bhaupur- Kalikadham  - Tendui            2.95
# 7221                 MRL15-karehane tikara to khalispur            5.00
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY
# 0                  2          1                8          1            0
# 1                  1          1                7          1            0
# 2                  1          0                5          1            1
# 3                  1          1                4          1            0
# 4                  0          3                2          1            0
# ...              ...        ...              ...        ...          ...
# 7217               0          3                1          1            0
# 7218               1          0                5          1            1
# 7219               1          0                4          1            1
# 7220               0          3                3          0            0
# 7221               1          2                5          1            1
#
# [7222 rows x 11 columns]

# %%
df1
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0             Agra   Achhnera     2016-2017         UP0177
# 1             Agra   Achhnera     2018-2019         UP0185
# 2             Agra   Achhnera     2021-2022        UP01103
# 3             Agra   Achhnera     2021-2022        UP01115
# 4             Agra   Achhnera     2021-2022         UP0188
# ...            ...        ...           ...            ...
# 7217      Varanasi   Sewapuri     2007-2008         UP7041
# 7218      Varanasi   Sewapuri     2012-2013         UP7043
# 7219      Varanasi   Sewapuri     2012-2013         UP7043
# 7220      Varanasi   Sewapuri     2012-2013         UP7049
# 7221      Varanasi   Sewapuri     2020-2021         UP7090
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2     MRL25-Raibha to Kirawali Achhnera Road via Dha...            5.00
# 3           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 4                           T01-Achhrena to Kitham Road           12.00
# ...                                                 ...             ...
# 7217         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7218         SH-98 - Jogiyapur- Beerapur- Jogapur road             3.25
# 7219                              SH-98 - Shirhira road            2.80
# 7220                      Bhaupur- Kalikadham  - Tendui            2.95
# 7221                 MRL15-karehane tikara to khalispur            5.00
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY
# 0                  2          1                8          1            0
# 1                  1          1                7          1            0
# 2                  1          0                5          1            1
# 3                  1          1                4          1            0
# 4                  0          3                2          1            0
# ...              ...        ...              ...        ...          ...
# 7217               0          3                1          1            0
# 7218               1          0                5          1            1
# 7219               1          0                4          1            1
# 7220               0          3                3          0            0
# 7221               1          2                5          1            1
#
# [7222 rows x 11 columns]

# %%
df1['GRADE_DIFFER'] = abs(df1['NQM_GRADE']-df1['SQM_GRADE'])
df1['INS_DIFFER'] = abs(df1['NQM_INSP_COUNT']-df1['SQM_INSP_COUNT1'])

# %%
df1
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0             Agra   Achhnera     2016-2017         UP0177
# 1             Agra   Achhnera     2018-2019         UP0185
# 2             Agra   Achhnera     2021-2022        UP01103
# 3             Agra   Achhnera     2021-2022        UP01115
# 4             Agra   Achhnera     2021-2022         UP0188
# ...            ...        ...           ...            ...
# 7217      Varanasi   Sewapuri     2007-2008         UP7041
# 7218      Varanasi   Sewapuri     2012-2013         UP7043
# 7219      Varanasi   Sewapuri     2012-2013         UP7043
# 7220      Varanasi   Sewapuri     2012-2013         UP7049
# 7221      Varanasi   Sewapuri     2020-2021         UP7090
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2     MRL25-Raibha to Kirawali Achhnera Road via Dha...            5.00
# 3           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 4                           T01-Achhrena to Kitham Road           12.00
# ...                                                 ...             ...
# 7217         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7218         SH-98 - Jogiyapur- Beerapur- Jogapur road             3.25
# 7219                              SH-98 - Shirhira road            2.80
# 7220                      Bhaupur- Kalikadham  - Tendui            2.95
# 7221                 MRL15-karehane tikara to khalispur            5.00
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY  \
# 0                  2          1                8          1            0
# 1                  1          1                7          1            0
# 2                  1          0                5          1            1
# 3                  1          1                4          1            0
# 4                  0          3                2          1            0
# ...              ...        ...              ...        ...          ...
# 7217               0          3                1          1            0
# 7218               1          0                5          1            1
# 7219               1          0                4          1            1
# 7220               0          3                3          0            0
# 7221               1          2                5          1            1
#
#       GRADE_DIFFER  INS_DIFFER
# 0                0           6
# 1                0           6
# 2                1           4
# 3                0           3
# 4                2           2
# ...            ...         ...
# 7217             2           1
# 7218             1           4
# 7219             1           3
# 7220             3           3
# 7221             1           4
#
# [7222 rows x 13 columns]

# %%
df1['DISCREPANCY_LEVEL'] = np.where(df1['GRADE_DIFFER']==0,0,np.nan)
df3=df1.dropna()
df3
# Out:
#      DISTRICT_NAME      BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0             Agra        Achhnera     2016-2017         UP0177
# 1             Agra        Achhnera     2018-2019         UP0185
# 3             Agra        Achhnera     2021-2022        UP01115
# 5             Agra           Akola     2016-2017         UP0173
# 8             Agra           Akola     2021-2022         UP0187
# ...            ...             ...           ...            ...
# 7200      Varanasi  Kashividyapith     2016-2017         UP7067
# 7202      Varanasi  Kashividyapith     2016-2017         UP7070
# 7206      Varanasi          Pindra     2012-2013         UP7045
# 7207      Varanasi          Pindra     2012-2013         UP7046
# 7215      Varanasi          Pindra     2020-2021         UP7079
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 3           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 5          MRL02-C.A.T.K. Road to Kirawali Kagarol Road            5.75
# 8                    T04-Basaia Raimol to NH-11 Midakur           11.55
# ...                                                 ...             ...
# 7200          T04-Nh-2 By Pass To Faridpur Kadipur Road            5.20
# 7202  ML08-Lahartara to Akelawa km 4  to Mahmoodpur ...            6.00
# 7206           Phoolpur- Sindhora to  - Gajokhar  road             6.50
# 7207              SH- 98 road  - Mangari- Sindhora road            8.00
# 7215            MRL11-NH 56 km 259 to Kaharka  jhanjour            6.50
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY  \
# 0                  2          1                8          1            0
# 1                  1          1                7          1            0
# 3                  1          1                4          1            0
# 5                  1          1                9          1            0
# 8                  1          1                2          1            0
# ...              ...        ...              ...        ...          ...
# 7200               1          1               10          1            0
# 7202               1          1                8          1            0
# 7206               1          1                6          1            0
# 7207               1          1                7          1            0
# 7215               1          1                5          1            0
#
#       GRADE_DIFFER  INS_DIFFER  DISCREPANCY_LEVEL
# 0                0           6                0.0
# 1                0           6                0.0
# 3                0           3                0.0
# 5                0           8                0.0
# 8                0           1                0.0
# ...            ...         ...                ...
# 7200             0           9                0.0
# 7202             0           7                0.0
# 7206             0           5                0.0
# 7207             0           6                0.0
# 7215             0           4                0.0
#
# [2559 rows x 14 columns]

# %%
df1['DISCREPANCY_LEVEL'] = np.where((df1['INS_DIFFER']<=3)&
                                    (((df1['NQM_GRADE']==1) &(df1['SQM_GRADE']==0))|((df1['NQM_GRADE']==0)&(df1['SQM_GRADE']==1))),1,np.nan)
df4=df1.dropna()
df4
# Out:
#       DISTRICT_NAME      BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 19             Agra             Bah     2020-2021         UP0195
# 98          Aligarh         Atrauli     2013-2014          UP263
# 188   Ambedkarnagar        Akbarpur     2011-2012         UP0463
# 243   Ambedkarnagar        Katehari     2006-2007         UP0440
# 250   Ambedkarnagar        Katehari     2012-2013         UP0469
# ...             ...             ...           ...            ...
# 7078          Unnao        Miyaganj     2012-2013         UP6993
# 7161       Varanasi        Baragaon     2007-2008         UP7035
# 7195       Varanasi  Kashividyapith     2007-2008         UP7042
# 7204       Varanasi  Kashividyapith     2020-2021         UP7083
# 7219       Varanasi        Sewapuri     2012-2013         UP7043
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 19                 MRL18-Bah Bateswar Road to Nagla Ent           5.000
# 98                            T02-Narona 12 No.to Barla          15.000
# 188                                  L.D Km-6 - Samaisa           3.500
# 243                                   Maharua - Dostpur           7.950
# 250                                Tiwaripur - Bakhopur           0.600
# ...                                                 ...             ...
# 7078  L085 SRC Km-27 Kanigawn Road (Makhdumpur Shah ...           3.000
# 7161               Remaining part of Newada - Kathiraon           3.600
# 7195       Panchkoshi road Gram sabha Aurhe  - Bachchaw           2.675
# 7204  MRL01-Chhitauni Kot via Narottampur Khurd  to ...           8.900
# 7219                              SH-98 - Shirhira road           2.800
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY  \
# 19                 1          0                4          1            1
# 98                 3          0                5          1            1
# 188                1          1                4          0            1
# 243                1          0                1          1            1
# 250                1          0                4          1            1
# ...              ...        ...              ...        ...          ...
# 7078               1          0                3          1            1
# 7161               1          0                1          1            1
# 7195               1          0                1          1            1
# 7204               1          0                4          1            1
# 7219               1          0                4          1            1
#
#       GRADE_DIFFER  INS_DIFFER  DISCREPANCY_LEVEL
# 19               1           3                1.0
# 98               1           2                1.0
# 188              1           3                1.0
# 243              1           0                1.0
# 250              1           3                1.0
# ...            ...         ...                ...
# 7078             1           2                1.0
# 7161             1           0                1.0
# 7195             1           0                1.0
# 7204             1           3                1.0
# 7219             1           3                1.0
#
# [227 rows x 14 columns]

# %%
df1['DISCREPANCY_LEVEL'] = np.where((df1['INS_DIFFER']>3)&
                                    (((df1['NQM_GRADE']==1) &(df1['SQM_GRADE']==0))|((df1['NQM_GRADE']==0)&(df1['SQM_GRADE']==1))),2,np.nan)
df5=df1.dropna()
df5
# Out:
#      DISTRICT_NAME      BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 2             Agra        Achhnera     2021-2022        UP01103
# 16            Agra             Bah     2012-2013         UP0156
# 26            Agra        Bichpuri     2013-2014          UP169
# 32            Agra        Etmadpur     2016-2017         UP0179
# 51            Agra          Jagner     2013-2014          UP172
# ...            ...             ...           ...            ...
# 7119         Unnao         Safipur     2012-2013         UP6971
# 7121         Unnao         Safipur     2018-2019        UP69129
# 7178      Varanasi        Cholapur     2016-2017         UP7072
# 7201      Varanasi  Kashividyapith     2016-2017         UP7069
# 7218      Varanasi        Sewapuri     2012-2013         UP7043
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 2     MRL25-Raibha to Kirawali Achhnera Road via Dha...            5.00
# 16     Nandgawan Kenjara -  UMretha Pinahat Road (NKUP)            9.00
# 26    MRL01-S H-39 to Nonena-Jat (NH-3) via Bamroli ...            7.55
# 32          ML06-Mohisinabad to Barhan via sarai Jairam            5.20
# 51         MRL05-C A T K Kasimpur Singaich to Dahagawan            5.85
# ...                                                 ...             ...
# 7119           L 042 SRC km 53  Hazikhera - Hasan Khera            1.70
# 7121                  L067-SAFIPUR PARIYAR TO KATIYAMAU            7.35
# 7178  ML03-Katharganj - Niyardih To Chahin Hazepur Road            7.10
# 7201  T03-NH-2 To Delhana Bansepur Paterwa Karsada Road            5.20
# 7218         SH-98 - Jogiyapur- Beerapur- Jogapur road             3.25
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY  \
# 2                  1          0                5          1            1
# 16                 1          0                7          1            1
# 26                 2          1                7          0            1
# 32                 2          0                8          1            1
# 51                 2          0                6          1            1
# ...              ...        ...              ...        ...          ...
# 7119               1          0                5          1            1
# 7121               1          0                6          1            1
# 7178               1          0                8          1            1
# 7201               1          0                8          1            1
# 7218               1          0                5          1            1
#
#       GRADE_DIFFER  INS_DIFFER  DISCREPANCY_LEVEL
# 2                1           4                2.0
# 16               1           6                2.0
# 26               1           5                2.0
# 32               1           6                2.0
# 51               1           4                2.0
# ...            ...         ...                ...
# 7119             1           4                2.0
# 7121             1           5                2.0
# 7178             1           7                2.0
# 7201             1           7                2.0
# 7218             1           4                2.0
#
# [308 rows x 14 columns]

# %%
df1['DISCREPANCY_LEVEL'] = np.where((df1['NQM_GRADE'] == 2) | (df1['SQM_GRADE'] == 2), 3, np.nan)
df6 = df1.dropna()
df6
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 14            Agra        Bah     2011-2012         UP0153
# 15            Agra        Bah     2011-2012         UP0153
# 17            Agra        Bah     2012-2013        UP0161Z
# 31            Agra   Etmadpur     2012-2013         UP0160
# 48            Agra     Jagner     2011-2012         UP0154
# ...            ...        ...           ...            ...
# 7210      Varanasi     Pindra     2012-2013         UP7052
# 7211      Varanasi     Pindra     2012-2013         UP7052
# 7212      Varanasi     Pindra     2013-2014         UP7062
# 7213      Varanasi     Pindra     2016-2017         UP7068
# 7221      Varanasi   Sewapuri     2020-2021         UP7090
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 14                   Jarar Harlalpura Road - Sunsarpura            1.00
# 15                 Pura Kanera Basoni Road - Parvatpura            1.15
# 17                           Bhaupura -  Gungawali Road           11.40
# 31                              Barhan -  Kurgawan Road            6.00
# 48           Bharatpur Dholpur Road - Nagla Subdal Road            1.35
# ...                                                 ...             ...
# 7210                          Pindra-Belwan - Nindanpur            3.00
# 7211  Rameshwar - Badagaon Pancho pandawa-Rasulpur T...            4.80
# 7212  MRL21-bhojubir sindhora road to garkhara dasra...            5.00
# 7213                             ML04-Nh-56 To Aurawn              5.50
# 7221                 MRL15-karehane tikara to khalispur            5.00
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY  \
# 14                 0          3                5          2            0
# 15                 0          3                6          2            0
# 17                 1          2                6          1            1
# 31                 1          2                8          0            1
# 48                 0          3                4          2            0
# ...              ...        ...              ...        ...          ...
# 7210               1          2                7          0            1
# 7211               0          3                6          2            0
# 7212               1          2                6          1            1
# 7213               1          2                9          1            1
# 7221               1          2                5          1            1
#
#       GRADE_DIFFER  INS_DIFFER  DISCREPANCY_LEVEL
# 14               1           5                3.0
# 15               1           6                3.0
# 17               1           5                3.0
# 31               2           7                3.0
# 48               1           4                3.0
# ...            ...         ...                ...
# 7210             2           6                3.0
# 7211             1           6                3.0
# 7212             1           5                3.0
# 7213             1           8                3.0
# 7221             1           4                3.0
#
# [1192 rows x 14 columns]

# %%
df1['DISCREPANCY_LEVEL'] = np.where((df1['NQM_GRADE'] == 3) | (df1['SQM_GRADE'] == 3), 0, np.nan)
df7 = df1.dropna()
df7
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 4             Agra   Achhnera     2021-2022         UP0188
# 6             Agra      Akola     2021-2022        UP01123
# 7             Agra      Akola     2021-2022        UP01128
# 10            Agra      Akola     2021-2022         UP0199
# 11            Agra        Bah     2007-2008         UP0149
# ...            ...        ...           ...            ...
# 7211      Varanasi     Pindra     2012-2013         UP7052
# 7214      Varanasi     Pindra     2020-2021         UP7078
# 7216      Varanasi   Sewapuri     2007-2008         UP7040
# 7217      Varanasi   Sewapuri     2007-2008         UP7041
# 7220      Varanasi   Sewapuri     2012-2013         UP7049
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 4                           T01-Achhrena to Kitham Road           12.00
# 6            MRL01-Kirawali Kagarol Road to Garhi Nandu            5.25
# 7                           MRL09-NH-11 to Davli Karara            6.00
# 10                MRL06-Kirawali Kagarol road to soniga            5.00
# 11          Pura Kanera  - Pardkoli via Lakhanpura Road            4.74
# ...                                                 ...             ...
# 7211  Rameshwar - Badagaon Pancho pandawa-Rasulpur T...            4.80
# 7214            MRL05-NH 56 Km 266 to Ahrak - Babatpur             5.00
# 7216       SH-87- Badaura  - Kardhana Tikara Mirzamurad            5.50
# 7217         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7220                      Bhaupur- Kalikadham  - Tendui            2.95
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY  \
# 4                  0          3                2          1            0
# 6                  0          3                2          1            0
# 7                  0          3                3          1            0
# 10                 0          3                4          1            0
# 11                 0          3                1          1            0
# ...              ...        ...              ...        ...          ...
# 7211               0          3                6          2            0
# 7214               0          3                4          1            0
# 7216               0          3                1          1            0
# 7217               0          3                1          1            0
# 7220               0          3                3          0            0
#
#       GRADE_DIFFER  INS_DIFFER  DISCREPANCY_LEVEL
# 4                2           2                0.0
# 6                2           2                0.0
# 7                2           3                0.0
# 10               2           4                0.0
# 11               2           1                0.0
# ...            ...         ...                ...
# 7211             1           6                0.0
# 7214             2           4                0.0
# 7216             2           1                0.0
# 7217             2           1                0.0
# 7220             3           3                0.0
#
# [3451 rows x 14 columns]

# %%
df8 = [df3, df4, df5, df6, df7]  
  
df9 = pd.concat(df8)
df9.reset_index(inplace=True)

# %%
df11 = df9.drop(['index'], axis='columns')

# %%
df2 = df11
df11
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0             Agra   Achhnera     2016-2017         UP0177
# 1             Agra   Achhnera     2018-2019         UP0185
# 2             Agra   Achhnera     2021-2022        UP01115
# 3             Agra      Akola     2016-2017         UP0173
# 4             Agra      Akola     2021-2022         UP0187
# ...            ...        ...           ...            ...
# 7732      Varanasi     Pindra     2012-2013         UP7052
# 7733      Varanasi     Pindra     2020-2021         UP7078
# 7734      Varanasi   Sewapuri     2007-2008         UP7040
# 7735      Varanasi   Sewapuri     2007-2008         UP7041
# 7736      Varanasi   Sewapuri     2012-2013         UP7049
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 3          MRL02-C.A.T.K. Road to Kirawali Kagarol Road            5.75
# 4                    T04-Basaia Raimol to NH-11 Midakur           11.55
# ...                                                 ...             ...
# 7732  Rameshwar - Badagaon Pancho pandawa-Rasulpur T...            4.80
# 7733            MRL05-NH 56 Km 266 to Ahrak - Babatpur             5.00
# 7734       SH-87- Badaura  - Kardhana Tikara Mirzamurad            5.50
# 7735         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7736                      Bhaupur- Kalikadham  - Tendui            2.95
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY  \
# 0                  2          1                8          1            0
# 1                  1          1                7          1            0
# 2                  1          1                4          1            0
# 3                  1          1                9          1            0
# 4                  1          1                2          1            0
# ...              ...        ...              ...        ...          ...
# 7732               0          3                6          2            0
# 7733               0          3                4          1            0
# 7734               0          3                1          1            0
# 7735               0          3                1          1            0
# 7736               0          3                3          0            0
#
#       GRADE_DIFFER  INS_DIFFER  DISCREPANCY_LEVEL
# 0                0           6                0.0
# 1                0           6                0.0
# 2                0           3                0.0
# 3                0           8                0.0
# 4                0           1                0.0
# ...            ...         ...                ...
# 7732             1           6                0.0
# 7733             2           4                0.0
# 7734             2           1                0.0
# 7735             2           1                0.0
# 7736             3           3                0.0
#
# [7737 rows x 14 columns]

# %%
df9['DISCREPANCY_S'] = df9['DISCREPANCY_LEVEL']*(1/df9['DISCREPANCY_LEVEL'])

# %%
df9['DISCREPANCY_S'].unique()
# Out:
# array([nan,  1.])

# %%
df9['DISCREPANCY_S'] = df9['DISCREPANCY_S'].replace(np.nan, 0)

# %%
df9.to_csv('Data for deep learning.csv',index=False)

# %%
df9['DISCREPANCY_LEVEL'].replace(0, 'No Descripancy', inplace=True)
df9['DISCREPANCY_LEVEL'].replace(1, 'High', inplace=True)
df9['DISCREPANCY_LEVEL'].replace(2, 'Medium', inplace=True)
df9['DISCREPANCY_LEVEL'].replace(3, 'Low', inplace=True)

# %%
df9
# Out:
#       index DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0         0          Agra   Achhnera     2016-2017         UP0177
# 1         1          Agra   Achhnera     2018-2019         UP0185
# 2         3          Agra   Achhnera     2021-2022        UP01115
# 3         5          Agra      Akola     2016-2017         UP0173
# 4         8          Agra      Akola     2021-2022         UP0187
# ...     ...           ...        ...           ...            ...
# 7732   7211      Varanasi     Pindra     2012-2013         UP7052
# 7733   7214      Varanasi     Pindra     2020-2021         UP7078
# 7734   7216      Varanasi   Sewapuri     2007-2008         UP7040
# 7735   7217      Varanasi   Sewapuri     2007-2008         UP7041
# 7736   7220      Varanasi   Sewapuri     2012-2013         UP7049
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 3          MRL02-C.A.T.K. Road to Kirawali Kagarol Road            5.75
# 4                    T04-Basaia Raimol to NH-11 Midakur           11.55
# ...                                                 ...             ...
# 7732  Rameshwar - Badagaon Pancho pandawa-Rasulpur T...            4.80
# 7733            MRL05-NH 56 Km 266 to Ahrak - Babatpur             5.00
# 7734       SH-87- Badaura  - Kardhana Tikara Mirzamurad            5.50
# 7735         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7736                      Bhaupur- Kalikadham  - Tendui            2.95
#
#       NQM_INSP_COUNT  NQM_GRADE  SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY  \
# 0                  2          1                8          1            0
# 1                  1          1                7          1            0
# 2                  1          1                4          1            0
# 3                  1          1                9          1            0
# 4                  1          1                2          1            0
# ...              ...        ...              ...        ...          ...
# 7732               0          3                6          2            0
# 7733               0          3                4          1            0
# 7734               0          3                1          1            0
# 7735               0          3                1          1            0
# 7736               0          3                3          0            0
#
#       GRADE_DIFFER  INS_DIFFER DISCREPANCY_LEVEL  DISCREPANCY_S
# 0                0           6    No Descripancy            0.0
# 1                0           6    No Descripancy            0.0
# 2                0           3    No Descripancy            0.0
# 3                0           8    No Descripancy            0.0
# 4                0           1    No Descripancy            0.0
# ...            ...         ...               ...            ...
# 7732             1           6    No Descripancy            0.0
# 7733             2           4    No Descripancy            0.0
# 7734             2           1    No Descripancy            0.0
# 7735             2           1    No Descripancy            0.0
# 7736             3           3    No Descripancy            0.0
#
# [7737 rows x 16 columns]

# %%
df9['NQM_GRADE'].replace(1, 'Satisfactory', inplace=True)
df9['NQM_GRADE'].replace(0, 'Unsatisfactory', inplace=True)
df9['NQM_GRADE'].replace(2, 'Required Improvement', inplace=True)
df9['NQM_GRADE'].replace(3, 'Uninspected', inplace=True)

# %%
df9['SQM_GRADE'].replace(1, 'Satisfactory', inplace=True)
df9['SQM_GRADE'].replace(0, 'Unsatisfactory', inplace=True)
df9['SQM_GRADE'].replace(2, 'Required Improvement', inplace=True)
df9['SQM_GRADE'].replace(3, 'Uninspected', inplace=True)

# %%
df9
# Out:
#       index DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0         0          Agra   Achhnera     2016-2017         UP0177
# 1         1          Agra   Achhnera     2018-2019         UP0185
# 2         3          Agra   Achhnera     2021-2022        UP01115
# 3         5          Agra      Akola     2016-2017         UP0173
# 4         8          Agra      Akola     2021-2022         UP0187
# ...     ...           ...        ...           ...            ...
# 7732   7211      Varanasi     Pindra     2012-2013         UP7052
# 7733   7214      Varanasi     Pindra     2020-2021         UP7078
# 7734   7216      Varanasi   Sewapuri     2007-2008         UP7040
# 7735   7217      Varanasi   Sewapuri     2007-2008         UP7041
# 7736   7220      Varanasi   Sewapuri     2012-2013         UP7049
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 3          MRL02-C.A.T.K. Road to Kirawali Kagarol Road            5.75
# 4                    T04-Basaia Raimol to NH-11 Midakur           11.55
# ...                                                 ...             ...
# 7732  Rameshwar - Badagaon Pancho pandawa-Rasulpur T...            4.80
# 7733            MRL05-NH 56 Km 266 to Ahrak - Babatpur             5.00
# 7734       SH-87- Badaura  - Kardhana Tikara Mirzamurad            5.50
# 7735         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7736                      Bhaupur- Kalikadham  - Tendui            2.95
#
#       NQM_INSP_COUNT     NQM_GRADE  SQM_INSP_COUNT1             SQM_GRADE  \
# 0                  2  Satisfactory                8          Satisfactory
# 1                  1  Satisfactory                7          Satisfactory
# 2                  1  Satisfactory                4          Satisfactory
# 3                  1  Satisfactory                9          Satisfactory
# 4                  1  Satisfactory                2          Satisfactory
# ...              ...           ...              ...                   ...
# 7732               0   Uninspected                6  Required Improvement
# 7733               0   Uninspected                4          Satisfactory
# 7734               0   Uninspected                1          Satisfactory
# 7735               0   Uninspected                1          Satisfactory
# 7736               0   Uninspected                3        Unsatisfactory
#
#       DISCREPANCY  GRADE_DIFFER  INS_DIFFER DISCREPANCY_LEVEL  DISCREPANCY_S
# 0               0             0           6    No Descripancy            0.0
# 1               0             0           6    No Descripancy            0.0
# 2               0             0           3    No Descripancy            0.0
# 3               0             0           8    No Descripancy            0.0
# 4               0             0           1    No Descripancy            0.0
# ...           ...           ...         ...               ...            ...
# 7732            0             1           6    No Descripancy            0.0
# 7733            0             2           4    No Descripancy            0.0
# 7734            0             2           1    No Descripancy            0.0
# 7735            0             2           1    No Descripancy            0.0
# 7736            0             3           3    No Descripancy            0.0
#
# [7737 rows x 16 columns]

# %%
df10 = df9.drop(['GRADE_DIFFER','INS_DIFFER','index'], axis='columns')
df10['DISCREPANCY']=df10['DISCREPANCY_S']

# %%
df10.to_csv('Data for Power BI.csv')

# %%
df9
# Out:
#       index DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0         0          Agra   Achhnera     2016-2017         UP0177
# 1         1          Agra   Achhnera     2018-2019         UP0185
# 2         3          Agra   Achhnera     2021-2022        UP01115
# 3         5          Agra      Akola     2016-2017         UP0173
# 4         8          Agra      Akola     2021-2022         UP0187
# ...     ...           ...        ...           ...            ...
# 7732   7211      Varanasi     Pindra     2012-2013         UP7052
# 7733   7214      Varanasi     Pindra     2020-2021         UP7078
# 7734   7216      Varanasi   Sewapuri     2007-2008         UP7040
# 7735   7217      Varanasi   Sewapuri     2007-2008         UP7041
# 7736   7220      Varanasi   Sewapuri     2012-2013         UP7049
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ML01-NH-2 (Km186) to Bichpuri Achhnera Road vi...            9.20
# 1     MRL08-A B Road to NH-11 via Garhi Chandrabhan ...           10.20
# 2           MRL13-Kirawali to Kirya via Ninwaya Nagaria            8.30
# 3          MRL02-C.A.T.K. Road to Kirawali Kagarol Road            5.75
# 4                    T04-Basaia Raimol to NH-11 Midakur           11.55
# ...                                                 ...             ...
# 7732  Rameshwar - Badagaon Pancho pandawa-Rasulpur T...            4.80
# 7733            MRL05-NH 56 Km 266 to Ahrak - Babatpur             5.00
# 7734       SH-87- Badaura  - Kardhana Tikara Mirzamurad            5.50
# 7735         Panchkoshi- Rameshwar  - Jagapatti Paterwa            3.50
# 7736                      Bhaupur- Kalikadham  - Tendui            2.95
#
#       NQM_INSP_COUNT     NQM_GRADE  SQM_INSP_COUNT1             SQM_GRADE  \
# 0                  2  Satisfactory                8          Satisfactory
# 1                  1  Satisfactory                7          Satisfactory
# 2                  1  Satisfactory                4          Satisfactory
# 3                  1  Satisfactory                9          Satisfactory
# 4                  1  Satisfactory                2          Satisfactory
# ...              ...           ...              ...                   ...
# 7732               0   Uninspected                6  Required Improvement
# 7733               0   Uninspected                4          Satisfactory
# 7734               0   Uninspected                1          Satisfactory
# 7735               0   Uninspected                1          Satisfactory
# 7736               0   Uninspected                3        Unsatisfactory
#
#       DISCREPANCY  GRADE_DIFFER  INS_DIFFER DISCREPANCY_LEVEL  DISCREPANCY_S
# 0               0             0           6    No Descripancy            0.0
# 1               0             0           6    No Descripancy            0.0
# 2               0             0           3    No Descripancy            0.0
# 3               0             0           8    No Descripancy            0.0
# 4               0             0           1    No Descripancy            0.0
# ...           ...           ...         ...               ...            ...
# 7732            0             1           6    No Descripancy            0.0
# 7733            0             2           4    No Descripancy            0.0
# 7734            0             2           1    No Descripancy            0.0
# 7735            0             2           1    No Descripancy            0.0
# 7736            0             3           3    No Descripancy            0.0
#
# [7737 rows x 16 columns]

# %%
u = df10.groupby(['DISTRICT_NAME']).sum()
# Out:
# C:\Users\Nitin Yadav\AppData\Local\Temp\ipykernel_27724\3367044187.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   u = df10.groupby(['DISTRICT_NAME']).sum()

# %%
x=u['DISCREPANCY_S'].sort_values(ascending=False).head()
x
# Out:
# DISTRICT_NAME
# Fatehpur      67.0
# Hardoi        65.0
# Sitapur       59.0
# Barabanki     54.0
# Pratapgarh    53.0
# Name: DISCREPANCY_S, dtype: float64

# %%
x1=u['NQM_INSP_COUNT'].sort_values(ascending=True).head()
x1
# Out:
# DISTRICT_NAME
# S.R. Nagar(Bhadohi)     2
# Mahoba                  9
# J.B.F.Nagar            13
# Mainpuri               14
# Hapur                  14
# Name: NQM_INSP_COUNT, dtype: int64

# %%
x2=u['SQM_INSP_COUNT1'].sort_values(ascending=True).head()
x2
# Out:
# DISTRICT_NAME
# Auraiya       166
# Ghaziabad     217
# Shamli        232
# Mahoba        246
# G.B. Nagar    249
# Name: SQM_INSP_COUNT1, dtype: int64

# %%
u1 = df10.groupby(['SANCTION_YEAR']).sum()
# Out:
# C:\Users\Nitin Yadav\AppData\Local\Temp\ipykernel_27724\3681190203.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   u1 = df10.groupby(['SANCTION_YEAR']).sum()

# %%
x3=u1['DISCREPANCY_S'].tail(5)
x3
# Out:
# SANCTION_YEAR
# 2017-2018      4.0
# 2018-2019     20.0
# 2019-2020      4.0
# 2020-2021    102.0
# 2021-2022    101.0
# Name: DISCREPANCY_S, dtype: float64

# %%
u2 = df10.groupby(['DISCREPANCY_LEVEL']).count()
u2
# Out:
#                    DISTRICT_NAME  BLOCK_NAME  SANCTION_YEAR  IMS_PACKAGE_ID  \
# DISCREPANCY_LEVEL
# High                         227         227            227             227
# Low                         1192        1192           1192            1192
# Medium                       308         308            308             308
# No Descripancy              6010        6010           6010            6010
#
#                    IMS_ROAD_NAME  IMS_PAV_LENGTH  NQM_INSP_COUNT  NQM_GRADE  \
# DISCREPANCY_LEVEL
# High                         227             227             227        227
# Low                         1192            1192            1192       1192
# Medium                       308             308             308        308
# No Descripancy              6010            6010            6010       6010
#
#                    SQM_INSP_COUNT1  SQM_GRADE  DISCREPANCY  DISCREPANCY_S
# DISCREPANCY_LEVEL
# High                           227        227          227            227
# Low                           1192       1192         1192           1192
# Medium                         308        308          308            308
# No Descripancy                6010       6010         6010           6010

# %%
x4=u2['DISCREPANCY'].sort_values(ascending=True).head()
x4
# Out:
# DISCREPANCY_LEVEL
# High               227
# Medium             308
# Low               1192
# No Descripancy    6010
# Name: DISCREPANCY, dtype: int64

# %%
print('1-Most Number of Discrepancies found in districts-',x,'\n\n',
      '2-Least Number of NQM inspection-',x1,'\n\n',
      '3-Least Number of SQM inspection-',x2,'\n\n',
      '4-Number Of Discrepancies in last 5 years-',x3,'\n\n',
      '5-Number Of Discrepancies Levelwise-',x4,'\n\n\n\n',
      'NOTE- 1-All The Results are based On a Deep Learning Model of 99.91% Accuracy','\n',
      '2-Discrepancies are Found on the basis of comparison between NQM and SQM')
# Out:
# 1-Most Number of Discrepancies found in districts- DISTRICT_NAME
# Fatehpur      67.0
# Hardoi        65.0
# Sitapur       59.0
# Barabanki     54.0
# Pratapgarh    53.0
# Name: DISCREPANCY_S, dtype: float64
#
#  2-Least Number of NQM inspection- DISTRICT_NAME
# S.R. Nagar(Bhadohi)     2
# Mahoba                  9
# J.B.F.Nagar            13
# Mainpuri               14
# Hapur                  14
# Name: NQM_INSP_COUNT, dtype: int64
#
#  3-Least Number of SQM inspection- DISTRICT_NAME
# Auraiya       166
# Ghaziabad     217
# Shamli        232
# Mahoba        246
# G.B. Nagar    249
# Name: SQM_INSP_COUNT1, dtype: int64
#
#  4-Number Of Discrepancies in last 5 years- SANCTION_YEAR
# 2017-2018      4.0
# 2018-2019     20.0
# 2019-2020      4.0
# 2020-2021    102.0
# 2021-2022    101.0
# Name: DISCREPANCY_S, dtype: float64
#
#  5-Number Of Discrepancies Levelwise- DISCREPANCY_LEVEL
# High               227
# Medium             308
# Low               1192
# No Descripancy    6010
# Name: DISCREPANCY, dtype: int64
#
#
#
#  NOTE- 1-All The Results are based On a Deep Learning Model of 99.91% Accuracy
#  2-Discrepancies are Found on the basis of comparison between NQM and SQM

# %%
nqm=pd.read_csv("C:\\Users\\Nitin Yadav\\OneDrive\\Documents\\NQM_Report.csv")

# %%
nqm
# Out:
#    District        Block                                          Road_name  \
# 0  Ariyalur    Andimadam          L060-Silambur to Thirukonam road (VR2180)
# 1  Ariyalur     Ariyalur                        poyyathanallur - illupaiyur
# 2  Ariyalur     Ariyalur           L073-AS road to Ameenabath road (VR2041)
# 3  Ariyalur     Ariyalur           L063-AA road to Kayarlabad road (VR2066)
# 4  Ariyalur     Ariyalur  L047-Karuppur Poiyyur - Oriyur - Nanangur road...
# 5  Ariyalur  Jayamkondam                           Meensurity - Kuttakkarai
# 6  Ariyalur  Jayamkondam  \t\nMRL12-Meikavalputhur-Veeracholapuram (via)...
#
#                 Monitor Name Inspection Date  Package  Start Chainage  \
# 0  Dange Pradeep Bhaskar rao      24-09-2016   TN3090               1
# 1          Sharma Deputy Lal      26-08-2018   TN1165               0
# 2  Dange Pradeep Bhaskar rao      23-09-2016   TN3082               0
# 3      Suresh Chandra Sharma      14-12-2018   TN3083               0
# 4      Suresh Chandra Sharma      14-12-2018   TN3086               0
# 5          Sharma Deputy Lal      26-04-2018   TN1166               0
# 6            Prakash Anugrah      16-09-2018  TN30105               0
#
#    End Chainage  Quality Arrangment  Attention To Quality  ...  Unnamed: 13  \
# 0         4.000                   1                     1  ...          NaN
# 1         5.500                   2                     2  ...          NaN
# 2         1.325                   1                     1  ...          NaN
# 3         1.250                   2                     2  ...          NaN
# 4         1.125                   2                     2  ...          NaN
# 5         1.000                   2                     2  ...          NaN
# 6         3.000                   1                     1  ...          NaN
#
#    Unnamed: 14  Cross Drainage Works  Unnamed: 16  \
# 0          NaN                     1          NaN
# 1          NaN                     2          NaN
# 2          NaN                     1          NaN
# 3          NaN                     2          NaN
# 4          NaN                     2          NaN
# 5          NaN                     2          NaN
# 6          NaN                     2          NaN
#
#    Road Furnitures And Markings  Unnamed: 18  Unnamed: 19  Maintenance  \
# 0                             1          NaN          NaN            2
# 1                             2          NaN          NaN            0
# 2                             1          NaN          NaN            2
# 3                             2          NaN          NaN            0
# 4                             2          NaN          NaN            0
# 5                             2          NaN          NaN            1
# 6                             1          NaN          NaN            2
#
#    Shoulders  pavement
# 0          2         2
# 1          0         1
# 2          2         2
# 3          0         1
# 4          0         0
# 5          2         1
# 6          2         2
#
# [7 rows x 23 columns]

# %%
nqm.columns
# Out:
# Index(['District', 'Block', 'Road_name', 'Monitor Name', 'Inspection Date',
#        'Package', 'Start Chainage', 'End Chainage', 'Quality Arrangment',
#        'Attention To Quality', 'Unnamed: 10', 'Geometrics',
#        'Base Course-Water Bound Macadam', 'Unnamed: 13', 'Unnamed: 14',
#        'Cross Drainage Works', 'Unnamed: 16', 'Road Furnitures And Markings',
#        'Unnamed: 18', 'Unnamed: 19', 'Maintenance', 'Shoulders', 'pavement'],
#       dtype='object')

# %%
nqm.dropna(axis='columns',inplace=True)

# %%
sqm=pd.read_csv("C:\\Users\\Nitin Yadav\\OneDrive\\Documents\\SQM_Report.csv")

# %%
sqm
# Out:
#    District        Block                                          Road_name  \
# 0  Ariyalur    Andimadam          L060-Silambur to Thirukonam road (VR2180)
# 1  Ariyalur     Ariyalur                        poyyathanallur - illupaiyur
# 2  Ariyalur     Ariyalur           L073-AS road to Ameenabath road (VR2041)
# 3  Ariyalur     Ariyalur           L063-AA road to Kayarlabad road (VR2066)
# 4  Ariyalur     Ariyalur  L047-Karuppur Poiyyur - Oriyur - Nanangur road...
# 5  Ariyalur  Jayamkondam                           Meensurity - Kuttakkarai
# 6  Ariyalur  Jayamkondam  \t\nMRL12-Meikavalputhur-Veeracholapuram (via)...
#
#       Monitor Name(SQM) Inspection Date(SQM) Package(SQM)  \
# 0  Durairaj Kumaraswamy           23-02-2016       TN3090
# 1           C Duraisamy           17-02-2018       TN1165
# 2          Y CHRISTDHAS           24-08-2016       TN3082
# 3   Thiruppathy Chithan           29-08-2017       TN3083
# 4     Muthuvalliappan M           22-02-2017       TN3086
# 5           Thangaraj D           25-11-2017       TN1166
# 6     Muthuvalliappan M           11-08-2018      TN30105
#
#    Start Chainage(SQM)  End Chainage(SQM)  Quality Arrangment(SQM)  \
# 0                    0              5.400                        1
# 1                    0              5.500                        2
# 2                    0              1.325                        1
# 3                    0              1.250                        2
# 4                    0              1.125                        2
# 5                    0              1.000                        2
# 6                    0              3.000                        1
#
#    Attention To Quality(SQM)  ...  Base Course-Water Bound Macadam(SQM)  \
# 0                          1  ...                                     2
# 1                          2  ...                                     2
# 2                          1  ...                                     1
# 3                          2  ...                                     1
# 4                          2  ...                                     1
# 5                          2  ...                                     2
# 6                          1  ...                                     1
#
#    Unnamed: 12  Unnamed: 13  Cross Drainage Works(SQM)  Unnamed: 15  \
# 0          NaN          NaN                          2          NaN
# 1          NaN          NaN                          2          NaN
# 2          NaN          NaN                          2          NaN
# 3          NaN          NaN                          2          NaN
# 4          NaN          NaN                          2          NaN
# 5          NaN          NaN                          2          NaN
# 6          NaN          NaN                          2          NaN
#
#    Road Furnitures And Markings(SQM)  Unnamed: 17  Maintenance(SQM)  \
# 0                                  1          NaN                 2
# 1                                  2          NaN                 1
# 2                                  1          NaN                 2
# 3                                  1          NaN                 2
# 4                                  1          NaN                 2
# 5                                  2          NaN                 1
# 6                                  1          NaN                 2
#
#    Shoulders(SQM)  pavement(SQM)
# 0               2              2
# 1               1              1
# 2               2              2
# 3               1              2
# 4               1              2
# 5               1              1
# 6               2              2
#
# [7 rows x 21 columns]

# %%
sqm.dropna(axis='columns',inplace=True)

# %%
nqm
# Out:
#    District        Block                                          Road_name  \
# 0  Ariyalur    Andimadam          L060-Silambur to Thirukonam road (VR2180)
# 1  Ariyalur     Ariyalur                        poyyathanallur - illupaiyur
# 2  Ariyalur     Ariyalur           L073-AS road to Ameenabath road (VR2041)
# 3  Ariyalur     Ariyalur           L063-AA road to Kayarlabad road (VR2066)
# 4  Ariyalur     Ariyalur  L047-Karuppur Poiyyur - Oriyur - Nanangur road...
# 5  Ariyalur  Jayamkondam                           Meensurity - Kuttakkarai
# 6  Ariyalur  Jayamkondam  \t\nMRL12-Meikavalputhur-Veeracholapuram (via)...
#
#                 Monitor Name Inspection Date  Package  Start Chainage  \
# 0  Dange Pradeep Bhaskar rao      24-09-2016   TN3090               1
# 1          Sharma Deputy Lal      26-08-2018   TN1165               0
# 2  Dange Pradeep Bhaskar rao      23-09-2016   TN3082               0
# 3      Suresh Chandra Sharma      14-12-2018   TN3083               0
# 4      Suresh Chandra Sharma      14-12-2018   TN3086               0
# 5          Sharma Deputy Lal      26-04-2018   TN1166               0
# 6            Prakash Anugrah      16-09-2018  TN30105               0
#
#    End Chainage  Quality Arrangment  Attention To Quality  Geometrics  \
# 0         4.000                   1                     1           1
# 1         5.500                   2                     2           2
# 2         1.325                   1                     1           1
# 3         1.250                   2                     2           2
# 4         1.125                   2                     2           2
# 5         1.000                   2                     2           2
# 6         3.000                   1                     1           1
#
#    Base Course-Water Bound Macadam  Cross Drainage Works  \
# 0                                0                     1
# 1                                2                     2
# 2                                0                     1
# 3                                2                     2
# 4                                2                     2
# 5                                2                     2
# 6                                2                     2
#
#    Road Furnitures And Markings  Maintenance  Shoulders  pavement
# 0                             1            2          2         2
# 1                             2            0          0         1
# 2                             1            2          2         2
# 3                             2            0          0         1
# 4                             2            0          0         0
# 5                             2            1          2         1
# 6                             1            2          2         2

# %%
sqm
# Out:
#    District        Block                                          Road_name  \
# 0  Ariyalur    Andimadam          L060-Silambur to Thirukonam road (VR2180)
# 1  Ariyalur     Ariyalur                        poyyathanallur - illupaiyur
# 2  Ariyalur     Ariyalur           L073-AS road to Ameenabath road (VR2041)
# 3  Ariyalur     Ariyalur           L063-AA road to Kayarlabad road (VR2066)
# 4  Ariyalur     Ariyalur  L047-Karuppur Poiyyur - Oriyur - Nanangur road...
# 5  Ariyalur  Jayamkondam                           Meensurity - Kuttakkarai
# 6  Ariyalur  Jayamkondam  \t\nMRL12-Meikavalputhur-Veeracholapuram (via)...
#
#       Monitor Name(SQM) Inspection Date(SQM) Package(SQM)  \
# 0  Durairaj Kumaraswamy           23-02-2016       TN3090
# 1           C Duraisamy           17-02-2018       TN1165
# 2          Y CHRISTDHAS           24-08-2016       TN3082
# 3   Thiruppathy Chithan           29-08-2017       TN3083
# 4     Muthuvalliappan M           22-02-2017       TN3086
# 5           Thangaraj D           25-11-2017       TN1166
# 6     Muthuvalliappan M           11-08-2018      TN30105
#
#    Start Chainage(SQM)  End Chainage(SQM)  Quality Arrangment(SQM)  \
# 0                    0              5.400                        1
# 1                    0              5.500                        2
# 2                    0              1.325                        1
# 3                    0              1.250                        2
# 4                    0              1.125                        2
# 5                    0              1.000                        2
# 6                    0              3.000                        1
#
#    Attention To Quality(SQM)  Geometrics(SQM)  \
# 0                          1                2
# 1                          2                2
# 2                          1                1
# 3                          2                1
# 4                          2                1
# 5                          2                2
# 6                          1                1
#
#    Base Course-Water Bound Macadam(SQM)  Cross Drainage Works(SQM)  \
# 0                                     2                          2
# 1                                     2                          2
# 2                                     1                          2
# 3                                     1                          2
# 4                                     1                          2
# 5                                     2                          2
# 6                                     1                          2
#
#    Road Furnitures And Markings(SQM)  Maintenance(SQM)  Shoulders(SQM)  \
# 0                                  1                 2               2
# 1                                  2                 1               1
# 2                                  1                 2               2
# 3                                  1                 2               1
# 4                                  1                 2               1
# 5                                  2                 1               1
# 6                                  1                 2               2
#
#    pavement(SQM)
# 0              2
# 1              1
# 2              2
# 3              2
# 4              2
# 5              1
# 6              2

# %%
print('***************** DETAILED REPORT *********************\n\n')
for i in range(nqm.District.count()):
    print('DISCREPANCY',i,':\n','STATE:','','\n','DISTRICT:',nqm.District[i],'\n',
         'BLOCK:',nqm.Block[i],'\n\n','SANCTION YEAR:','','\n','PACKAGE NUMBER:',nqm.Package[i],'\n',
         'ROAD NAME :',nqm.Road_name[i],'\n','ROAD LENGTH:','','\n\n',
         'NQM Inspection count:','','\n','NQM Grading:','','\n','NQM Name:',
          nqm['Monitor Name'][i],'\n','NQM Inspection date:',
          nqm['Inspection Date'][i],'\n','Status:','','\n','Start Chainage:',
          nqm['Start Chainage'][i],'\n','End Chainage:',nqm['End Chainage'][i],'\n\n',
          'SQM Inspection count:','','\n','SQM Grading:','','\n','SQM Name:',
          sqm['Monitor Name(SQM)'][i],'\n','SQM Inspection date:',
          sqm['Inspection Date(SQM)'][i],'\n','Status:','','\n','Start Chainage:',
          sqm['Start Chainage(SQM)'][i],'\n','End Chainage:',sqm['End Chainage(SQM)'][i],'\n\n'
          'Discrepancy item(s):',np.where(nqm['Quality Arrangment'][i]!=sqm['Quality Arrangment(SQM)'][i],'Quality Arrangment',''),' ',
          np.where(nqm['Attention To Quality'][i]!=sqm['Attention To Quality(SQM)'][i],'Attention To Quality',''),' ',
         np.where(nqm['Geometrics'][i]!=sqm['Geometrics(SQM)'][i],'Geometrics',''),' ',
         np.where(nqm['Base Course-Water Bound Macadam'][i]!=sqm['Base Course-Water Bound Macadam(SQM)'][i],'Base Course-Water Bound Macadam',''),' ',
         np.where(nqm['Cross Drainage Works'][i]!=sqm['Cross Drainage Works(SQM)'][i],'Cross Drainage Works',''),' ',
         np.where(nqm['Road Furnitures And Markings'][i]!=sqm['Road Furnitures And Markings(SQM)'][i],'Road Furnitures And Markings',''),' ',
         np.where(nqm['Maintenance'][i]!=sqm['Maintenance(SQM)'][i],'Maintenance',''),' ', 
         np.where(nqm['Shoulders'][i]!=sqm['Shoulders(SQM)'][i],'Shoulders',''),' ', 
         np.where(nqm['pavement'][i]!=sqm['pavement(SQM)'][i],'pavement',''),' '	)
# Out:
# ***************** DETAILED REPORT *********************
#
#
# DISCREPANCY 0 :
#  STATE:
#  DISTRICT: Ariyalur
#  BLOCK: Andimadam
#
#  SANCTION YEAR:
#  PACKAGE NUMBER: TN3090
#  ROAD NAME : L060-Silambur to Thirukonam road (VR2180)
#  ROAD LENGTH:
#
#  NQM Inspection count:
#  NQM Grading:
#  NQM Name: Dange Pradeep Bhaskar rao
#  NQM Inspection date: 24-09-2016
#  Status:
#  Start Chainage: 1
#  End Chainage: 4.0
#
#  SQM Inspection count:
#  SQM Grading:
#  SQM Name: Durairaj Kumaraswamy
#  SQM Inspection date: 23-02-2016
#  Status:
#  Start Chainage: 0
#  End Chainage: 5.4
#
# Discrepancy item(s):       Geometrics   Base Course-Water Bound Macadam   Cross Drainage Works
# DISCREPANCY 1 :
#  STATE:
#  DISTRICT: Ariyalur
#  BLOCK: Ariyalur
#
#  SANCTION YEAR:
#  PACKAGE NUMBER: TN1165
#  ROAD NAME : poyyathanallur - illupaiyur
#  ROAD LENGTH:
#
#  NQM Inspection count:
#  NQM Grading:
#  NQM Name: Sharma Deputy Lal
#  NQM Inspection date: 26-08-2018
#  Status:
#  Start Chainage: 0
#  End Chainage: 5.5
#
#  SQM Inspection count:
#  SQM Grading:
#  SQM Name: C Duraisamy
#  SQM Inspection date: 17-02-2018
#  Status:
#  Start Chainage: 0
#  End Chainage: 5.5
#
# Discrepancy item(s):                   Maintenance   Shoulders
# DISCREPANCY 2 :
#  STATE:
#  DISTRICT: Ariyalur
#  BLOCK: Ariyalur
#
#  SANCTION YEAR:
#  PACKAGE NUMBER: TN3082
#  ROAD NAME : L073-AS road to Ameenabath road (VR2041)
#  ROAD LENGTH:
#
#  NQM Inspection count:
#  NQM Grading:
#  NQM Name: Dange Pradeep Bhaskar rao
#  NQM Inspection date: 23-09-2016
#  Status:
#  Start Chainage: 0
#  End Chainage: 1.325
#
#  SQM Inspection count:
#  SQM Grading:
#  SQM Name: Y CHRISTDHAS
#  SQM Inspection date: 24-08-2016
#  Status:
#  Start Chainage: 0
#  End Chainage: 1.325
#
# Discrepancy item(s):          Base Course-Water Bound Macadam   Cross Drainage Works
# DISCREPANCY 3 :
#  STATE:
#  DISTRICT: Ariyalur
#  BLOCK: Ariyalur
#
#  SANCTION YEAR:
#  PACKAGE NUMBER: TN3083
#  ROAD NAME : L063-AA road to Kayarlabad road (VR2066)
#  ROAD LENGTH:
#
#  NQM Inspection count:
#  NQM Grading:
#  NQM Name: Suresh Chandra Sharma
#  NQM Inspection date: 14-12-2018
#  Status:
#  Start Chainage: 0
#  End Chainage: 1.25
#
#  SQM Inspection count:
#  SQM Grading:
#  SQM Name: Thiruppathy Chithan
#  SQM Inspection date: 29-08-2017
#  Status:
#  Start Chainage: 0
#  End Chainage: 1.25
#
# Discrepancy item(s):       Geometrics   Base Course-Water Bound Macadam      Road Furnitures And Markings   Maintenance   Shoulders   pavement
# DISCREPANCY 4 :
#  STATE:
#  DISTRICT: Ariyalur
#  BLOCK: Ariyalur
#
#  SANCTION YEAR:
#  PACKAGE NUMBER: TN3086
#  ROAD NAME : L047-Karuppur Poiyyur - Oriyur - Nanangur road to Puthur road (VR2067)
#  ROAD LENGTH:
#
#  NQM Inspection count:
#  NQM Grading:
#  NQM Name: Suresh Chandra Sharma
#  NQM Inspection date: 14-12-2018
#  Status:
#  Start Chainage: 0
#  End Chainage: 1.125
#
#  SQM Inspection count:
#  SQM Grading:
#  SQM Name: Muthuvalliappan M
#  SQM Inspection date: 22-02-2017
#  Status:
#  Start Chainage: 0
#  End Chainage: 1.125
#
# Discrepancy item(s):       Geometrics   Base Course-Water Bound Macadam      Road Furnitures And Markings   Maintenance   Shoulders   pavement
# DISCREPANCY 5 :
#  STATE:
#  DISTRICT: Ariyalur
#  BLOCK: Jayamkondam
#
#  SANCTION YEAR:
#  PACKAGE NUMBER: TN1166
#  ROAD NAME : Meensurity - Kuttakkarai
#  ROAD LENGTH:
#
#  NQM Inspection count:
#  NQM Grading:
#  NQM Name: Sharma Deputy Lal
#  NQM Inspection date: 26-04-2018
#  Status:
#  Start Chainage: 0
#  End Chainage: 1.0
#
#  SQM Inspection count:
#  SQM Grading:
#  SQM Name: Thangaraj D
#  SQM Inspection date: 25-11-2017
#  Status:
#  Start Chainage: 0
#  End Chainage: 1.0
#
# Discrepancy item(s):                      Shoulders
# DISCREPANCY 6 :
#  STATE:
#  DISTRICT: Ariyalur
#  BLOCK: Jayamkondam
#
#  SANCTION YEAR:
#  PACKAGE NUMBER: TN30105
#  ROAD NAME :
# MRL12-Meikavalputhur-Veeracholapuram (via) Mendevanallur road
#  ROAD LENGTH:
#
#  NQM Inspection count:
#  NQM Grading:
#  NQM Name: Prakash Anugrah
#  NQM Inspection date: 16-09-2018
#  Status:
#  Start Chainage: 0
#  End Chainage: 3.0
#
#  SQM Inspection count:
#  SQM Grading:
#  SQM Name: Muthuvalliappan M
#  SQM Inspection date: 11-08-2018
#  Status:
#  Start Chainage: 0
#  End Chainage: 3.0
#
# Discrepancy item(s):          Base Course-Water Bound Macadam
