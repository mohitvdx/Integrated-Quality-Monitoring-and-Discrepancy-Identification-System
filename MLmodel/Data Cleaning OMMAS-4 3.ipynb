# %%
import pandas as pd
import os

# Define the directory path where your CSV files are stored
directory_path = r"/Users/mohitverma/Desktop/projects/SIH23/DataForMLmodel"

# Initialize empty DataFrames for each of your CSV files
df = pd.DataFrame()
nqm = pd.DataFrame()
sqm = pd.DataFrame()

# Iterate over the files in the directory
for filename in os.listdir(directory_path):
    if filename.endswith(".csv"):
        file_path = os.path.join(directory_path, filename)

        # Check the file name and load the data into the corresponding DataFrame
        if 'NQM_SQM_Mon_Works_Detail_Report' in filename:
            df = pd.read_csv(file_path, skiprows=3)
        elif 'NQM_Report' in filename:
            nqm = pd.read_csv(file_path)
        elif 'SQM_Report' in filename:
            sqm = pd.read_csv(file_path)

# %%
df = pd.read_csv("/Users/mohitverma/Desktop/projects/SIH23/DataForMLmodel/NQM_SQM_Mon_Works_Detail_Report.csv",skiprows=3)

# %%
nqm=pd.read_csv("/Users/mohitverma/Desktop/projects/SIH23/DataForMLmodel/NQM_Report.csv")
sqm=pd.read_csv("/Users/mohitverma/Desktop/projects/SIH23/DataForMLmodel/SQM_Report.csv")

# %%
df
# Out:
#      Textbox39 Textbox37 Textbox35      Textbox33    Textbox31  Textbox11  \
# 0       Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 1       Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 2       Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 3       Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 4       Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# ...        ...       ...       ...            ...          ...        ...
# 1399    Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 1400    Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 1401    Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 1402    Sr.No.  District     Block  Sanction Year  Package No.  Road Name
# 1403    Sr.No.  District     Block  Sanction Year  Package No.  Road Name
#
#         Textbox15              Textbox17     Textbox13              Textbox19  \
# 0     Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 1     Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 2     Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 3     Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 4     Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# ...           ...                    ...           ...                    ...
# 1399  Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 1400  Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 1401  Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 1402  Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
# 1403  Road Length  NQM* Inspection Count  NQM* Grading  SQM# Inspection Count
#
#       ...                                      IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0     ...                                    Malagi Nandihal           3.000
# 1     ...              MRL3-Kagalagomba vasti to Kagalagomba           5.000
# 2     ...                    MRL1-Manneri RC to Dhanakshirur           7.800
# 3     ...                       MRL53-Neelagund to Mustigeri           4.270
# 4     ...             MRL49-Kabbalageri to NH-369 via Adagal           4.120
# ...   ...                                                ...             ...
# 1399  ...       MRL01-Yaddalli to Katagishahapur Via Hongera           4.300
# 1400  ...                    MRL05-Saidapur to Kanekal cross           6.090
# 1401  ...                            MRL09-Koilur to Helgera           4.065
# 1402  ...      MRL03-MDR near Abbetumkur to MDR near Hongera           5.395
# 1403  ...  MRL23-Road from MDR near Balched to Mdr Near B...           9.985
#
#      NQM_INSP_COUNT             NQM_GRADE SQM_INSP_COUNT1     SQM_GRADE  \
# 0                 0                    --               1  Satisfactory
# 1                 0                    --               2  Satisfactory
# 2                 0                    --               2  Satisfactory
# 3                 1          Satisfactory               2  Satisfactory
# 4                 1  Required Improvement               2  Satisfactory
# ...             ...                   ...             ...           ...
# 1399              1          Satisfactory               2  Satisfactory
# 1400              3          Satisfactory               4  Satisfactory
# 1401              1          Satisfactory               3  Satisfactory
# 1402              2          Satisfactory               2  Satisfactory
# 1403              2          Satisfactory               3  Satisfactory
#
#      Textbox67  Textbox72  Textbox73 Textbox74
# 0        Total  8,762.203        819     4,707
# 1        Total  8,762.203        819     4,707
# 2        Total  8,762.203        819     4,707
# 3        Total  8,762.203        819     4,707
# 4        Total  8,762.203        819     4,707
# ...        ...        ...        ...       ...
# 1399     Total  8,762.203        819     4,707
# 1400     Total  8,762.203        819     4,707
# 1401     Total  8,762.203        819     4,707
# 1402     Total  8,762.203        819     4,707
# 1403     Total  8,762.203        819     4,707
#
# [1404 rows x 26 columns]

# %%
df1 = df.drop(['Textbox39','Textbox37','Textbox35','Textbox33','Textbox31','Textbox11','Textbox15','Textbox17','Textbox13','Textbox19','Textbox21','Textbox40','Textbox67','Textbox72','Textbox73','Textbox74'], axis='columns')

# %%
df1
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0         Bagalkot     Badami     2000-2001         KN0101
# 1         Bagalkot     Badami     2013-2014         KN0142
# 2         Bagalkot     Badami     2013-2014         KN0143
# 3         Bagalkot     Badami     2020-2021         KN0150
# 4         Bagalkot     Badami     2020-2021         KN0151
# ...            ...        ...           ...            ...
# 1399        Yadgir    Yadgiri     2020-2021         KN2909
# 1400        Yadgir    Yadgiri     2020-2021         KN2911
# 1401        Yadgir    Yadgiri     2020-2021         KN2912
# 1402        Yadgir    Yadgiri     2020-2021         KN2913
# 1403        Yadgir    Yadgiri     2020-2021         KN2917
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0                                       Malagi Nandihal           3.000
# 1                 MRL3-Kagalagomba vasti to Kagalagomba           5.000
# 2                       MRL1-Manneri RC to Dhanakshirur           7.800
# 3                          MRL53-Neelagund to Mustigeri           4.270
# 4                MRL49-Kabbalageri to NH-369 via Adagal           4.120
# ...                                                 ...             ...
# 1399       MRL01-Yaddalli to Katagishahapur Via Hongera           4.300
# 1400                    MRL05-Saidapur to Kanekal cross           6.090
# 1401                            MRL09-Koilur to Helgera           4.065
# 1402      MRL03-MDR near Abbetumkur to MDR near Hongera           5.395
# 1403  MRL23-Road from MDR near Balched to Mdr Near B...           9.985
#
#       NQM_INSP_COUNT             NQM_GRADE  SQM_INSP_COUNT1     SQM_GRADE
# 0                  0                    --                1  Satisfactory
# 1                  0                    --                2  Satisfactory
# 2                  0                    --                2  Satisfactory
# 3                  1          Satisfactory                2  Satisfactory
# 4                  1  Required Improvement                2  Satisfactory
# ...              ...                   ...              ...           ...
# 1399               1          Satisfactory                2  Satisfactory
# 1400               3          Satisfactory                4  Satisfactory
# 1401               1          Satisfactory                3  Satisfactory
# 1402               2          Satisfactory                2  Satisfactory
# 1403               2          Satisfactory                3  Satisfactory
#
# [1404 rows x 10 columns]

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df1['NQM_GRADE'].replace('--', 'Uninspected', inplace=True)
df1['SQM_GRADE'].replace('--', 'Uninspected', inplace=True)

# %%
df1
# Out:
#      DISTRICT_NAME BLOCK_NAME SANCTION_YEAR IMS_PACKAGE_ID  \
# 0         Bagalkot     Badami     2000-2001         KN0101
# 1         Bagalkot     Badami     2013-2014         KN0142
# 2         Bagalkot     Badami     2013-2014         KN0143
# 3         Bagalkot     Badami     2020-2021         KN0150
# 4         Bagalkot     Badami     2020-2021         KN0151
# ...            ...        ...           ...            ...
# 1399        Yadgir    Yadgiri     2020-2021         KN2909
# 1400        Yadgir    Yadgiri     2020-2021         KN2911
# 1401        Yadgir    Yadgiri     2020-2021         KN2912
# 1402        Yadgir    Yadgiri     2020-2021         KN2913
# 1403        Yadgir    Yadgiri     2020-2021         KN2917
#
#                                           IMS_ROAD_NAME  IMS_PAV_LENGTH  \
# 0                                       Malagi Nandihal           3.000
# 1                 MRL3-Kagalagomba vasti to Kagalagomba           5.000
# 2                       MRL1-Manneri RC to Dhanakshirur           7.800
# 3                          MRL53-Neelagund to Mustigeri           4.270
# 4                MRL49-Kabbalageri to NH-369 via Adagal           4.120
# ...                                                 ...             ...
# 1399       MRL01-Yaddalli to Katagishahapur Via Hongera           4.300
# 1400                    MRL05-Saidapur to Kanekal cross           6.090
# 1401                            MRL09-Koilur to Helgera           4.065
# 1402      MRL03-MDR near Abbetumkur to MDR near Hongera           5.395
# 1403  MRL23-Road from MDR near Balched to Mdr Near B...           9.985
#
#       NQM_INSP_COUNT             NQM_GRADE  SQM_INSP_COUNT1     SQM_GRADE
# 0                  0           Uninspected                1  Satisfactory
# 1                  0           Uninspected                2  Satisfactory
# 2                  0           Uninspected                2  Satisfactory
# 3                  1          Satisfactory                2  Satisfactory
# 4                  1  Required Improvement                2  Satisfactory
# ...              ...                   ...              ...           ...
# 1399               1          Satisfactory                2  Satisfactory
# 1400               3          Satisfactory                4  Satisfactory
# 1401               1          Satisfactory                3  Satisfactory
# 1402               2          Satisfactory                2  Satisfactory
# 1403               2          Satisfactory                3  Satisfactory
#
# [1404 rows x 10 columns]

# %%
df1['SQM_GRADE'].replace('Satisfactory', 1, inplace=True)
df1['SQM_GRADE'].replace('Unsatisfactory', 0, inplace=True)
df1['SQM_GRADE'].replace('Required Improvement', 2, inplace=True)
df1['SQM_GRADE'].replace('Uninspected', 3, inplace=True)

# %%
df1['NQM_GRADE'].replace('Satisfactory', 1, inplace=True)
df1['NQM_GRADE'].replace('Unsatisfactory', 0, inplace=True)
df1['NQM_GRADE'].replace('Required Improvement', 2, inplace=True)
df1['NQM_GRADE'].replace('Uninspected', 3, inplace=True)

# %%
df1['DISCREPANCY'] = np.where((df1['NQM_GRADE'] == df1['SQM_GRADE'])|(df1['NQM_GRADE']==3)|(df1['SQM_GRADE']==3),0, 1)

# %%
df1['GRADE_DIFFER'] = abs(df1['NQM_GRADE']-df1['SQM_GRADE'])
df1['INS_DIFFER'] = abs(df1['NQM_INSP_COUNT']-df1['SQM_INSP_COUNT1'])

# %%
df1['DISCREPANCY_LEVEL'] = np.where(df1['GRADE_DIFFER']==0,0,np.nan)
df3=df1.dropna()

# %%
df1['DISCREPANCY_LEVEL'] = np.where((df1['INS_DIFFER']<=3)&
                                    (((df1['NQM_GRADE']==1) &(df1['SQM_GRADE']==0))|((df1['NQM_GRADE']==0)&(df1['SQM_GRADE']==1))),1,np.nan)
df4=df1.dropna()

# %%
df1['DISCREPANCY_LEVEL'] = np.where((df1['INS_DIFFER']>3)&
                                    (((df1['NQM_GRADE']==1) &(df1['SQM_GRADE']==0))|((df1['NQM_GRADE']==0)&(df1['SQM_GRADE']==1))),2,np.nan)
df5=df1.dropna()

# %%
df1['DISCREPANCY_LEVEL'] = np.where((df1['NQM_GRADE'] == 2) | (df1['SQM_GRADE'] == 2), 3, np.nan)
df6 = df1.dropna()

# %%
df1['DISCREPANCY_LEVEL'] = np.where((df1['NQM_GRADE'] == 3) | (df1['SQM_GRADE'] == 3), 0, np.nan)
df7 = df1.dropna()

# %%
df8 = [df3, df4, df5, df6, df7]  
  
df9 = pd.concat(df8)
df9.reset_index(inplace=True)

# %%
df11 = df9.drop(['index'], axis='columns')

# %%
df2 = df11

# %%
df9['DISCREPANCY_S'] = df9['DISCREPANCY_LEVEL']*(1/df9['DISCREPANCY_LEVEL'])

# %%
df9['DISCREPANCY_S'].unique()
# Out:
# array([nan,  1.])

# %%
df9['DISCREPANCY_S'] = df9['DISCREPANCY_S'].replace(np.nan, 0)

# %%
# df9.to_csv('Data for deep learning.csv',index=False)

# %%
df9['DISCREPANCY_LEVEL'].replace(0, 'No Descripancy', inplace=True)
df9['DISCREPANCY_LEVEL'].replace(1, 'High', inplace=True)
df9['DISCREPANCY_LEVEL'].replace(2, 'Medium', inplace=True)
df9['DISCREPANCY_LEVEL'].replace(3, 'Low', inplace=True)

# %%
df9['NQM_GRADE'].replace(1, 'Satisfactory', inplace=True)
df9['NQM_GRADE'].replace(0, 'Unsatisfactory', inplace=True)
df9['NQM_GRADE'].replace(2, 'Required Improvement', inplace=True)
df9['NQM_GRADE'].replace(3, 'Uninspected', inplace=True)

# %%
df9['SQM_GRADE'].replace(1, 'Satisfactory', inplace=True)
df9['SQM_GRADE'].replace(0, 'Unsatisfactory', inplace=True)
df9['SQM_GRADE'].replace(2, 'Required Improvement', inplace=True)
df9['SQM_GRADE'].replace(3, 'Uninspected', inplace=True)

# %%
df10 = df9.drop(['GRADE_DIFFER','INS_DIFFER','index'], axis='columns')
df10['DISCREPANCY']=df10['DISCREPANCY_S']

# %%
df10.to_csv('/Users/mohitverma/Desktop/projects/SIH23/PowerBI/Data for Power BI updated.csv', index=False)

# %%
u = df10.groupby(['DISTRICT_NAME']).sum()

# %%
x=u['DISCREPANCY_S'].sort_values(ascending=False).head()

# %%
x1=u['NQM_INSP_COUNT'].sort_values(ascending=True).head()

# %%
x2=u['SQM_INSP_COUNT1'].sort_values(ascending=True).head()

# %%
u1 = df10.groupby(['SANCTION_YEAR']).sum()

# %%
x3=u1['DISCREPANCY_S'].tail(5)

# %%
u2 = df10.groupby(['DISCREPANCY_LEVEL']).count()

# %%
x4=u2['DISCREPANCY'].sort_values(ascending=True).head()

# %%
print('1-Most Number of Discrepancies found in districts-',x,'\n\n',
      '2-Least Number of NQM inspection-',x1,'\n\n',
      '3-Least Number of SQM inspection-',x2,'\n\n',
      '4-Number Of Discrepancies in last 5 years-',x3,'\n\n',
      '5-Number Of Discrepancies Levelwise-',x4,'\n\n\n\n',
      'NOTE- 1-All The Results are based On a Deep Learning Model of 99.91% Accuracy','\n',
      '2-Discrepancies are Found on the basis of comparison between NQM and SQM')
# Out:
# 1-Most Number of Discrepancies found in districts- DISTRICT_NAME
# Dindigul          11.0
# Madurai            9.0
# Cuddalore          6.0
# Tiruvannamalai     5.0
# Tirupathur         4.0
# Name: DISCREPANCY_S, dtype: float64
#
#  2-Least Number of NQM inspection- DISTRICT_NAME
# Chengalpattu     0
# Kanniyakumari    0
# Tenkasi          0
# Kallakurichi     0
# The Nilgiris     1
# Name: NQM_INSP_COUNT, dtype: int64
#
#  3-Least Number of SQM inspection- DISTRICT_NAME
# Theni            36
# Kanniyakumari    38
# Tenkasi          50
# The Nilgiris     64
# Kanchipuram      86
# Name: SQM_INSP_COUNT1, dtype: int64
#
#  4-Number Of Discrepancies in last 5 years- SANCTION_YEAR
# 2018-2019     9.0
# 2019-2020    10.0
# 2020-2021    19.0
# 2021-2022     9.0
# 2022-2023     1.0
# Name: DISCREPANCY_S, dtype: float64
#
#  5-Number Of Discrepancies Levelwise- DISCREPANCY_LEVEL
# Medium               2
# High                10
# Low                 65
# No Descripancy    2879
# Name: DISCREPANCY, dtype: int64
#
#
#
#  NOTE- 1-All The Results are based On a Deep Learning Model of 99.91% Accuracy
#  2-Discrepancies are Found on the basis of comparison between NQM and SQM

# %%
nqm
# Out:
#         State Sanction Year  NQM I.C.       NQM_Grade       Status  \
# 0  Tamil Nadu     2015-2016         1  Unsatisfactory  In Progress
# 1  Tamil Nadu     2016-2017         2  Unsatisfactory  Maintenance
# 2  Tamil Nadu     2015-2016         1  Unsatisfactory  In Progress
# 3  Tamil Nadu     2015-2016         1  Unsatisfactory  Maintenance
# 4  Tamil Nadu     2014-2015         1  Unsatisfactory  Maintenance
# 5  Tamil Nadu     2016-2017         2  Unsatisfactory  Maintenance
# 6  Tamil Nadu     2014-2015         1    Satisfactory  Maintenance
#
#    Road_Length  District        Block  \
# 0        5.400  Ariyalur    Andimadam
# 1        5.520  Ariyalur     Ariyalur
# 2        1.325  Ariyalur     Ariyalur
# 3        1.250  Ariyalur     Ariyalur
# 4        1.125  Ariyalur     Ariyalur
# 5        1.000  Ariyalur  Jayamkondam
# 6        3.000  Ariyalur  Jayamkondam
#
#                                            Road_name  \
# 0          L060-Silambur to Thirukonam road (VR2180)
# 1                        poyyathanallur - illupaiyur
# 2           L073-AS road to Ameenabath road (VR2041)
# 3           L063-AA road to Kayarlabad road (VR2066)
# 4  L047-Karuppur Poiyyur - Oriyur - Nanangur road...
# 5                           Meensurity - Kuttakkarai
# 6  \t\nMRL12-Meikavalputhur-Veeracholapuram (via)...
#
#                 Monitor Name  ... Unnamed: 19 Unnamed: 20  \
# 0  Dange Pradeep Bhaskar rao  ...         NaN         NaN
# 1          Sharma Deputy Lal  ...         NaN         NaN
# 2  Dange Pradeep Bhaskar rao  ...         NaN         NaN
# 3      Suresh Chandra Sharma  ...         NaN         NaN
# 4      Suresh Chandra Sharma  ...         NaN         NaN
# 5          Sharma Deputy Lal  ...         NaN         NaN
# 6            Prakash Anugrah  ...         NaN         NaN
#
#    Cross Drainage Works  Unnamed: 22  Road Furnitures And Markings  \
# 0                     1          NaN                             1
# 1                     2          NaN                             2
# 2                     1          NaN                             1
# 3                     2          NaN                             2
# 4                     2          NaN                             2
# 5                     2          NaN                             2
# 6                     2          NaN                             1
#
#    Unnamed: 24  Unnamed: 25  Maintenance  Shoulders  pavement
# 0          NaN          NaN            2          2         2
# 1          NaN          NaN            0          0         1
# 2          NaN          NaN            2          2         2
# 3          NaN          NaN            0          0         1
# 4          NaN          NaN            0          0         0
# 5          NaN          NaN            1          2         1
# 6          NaN          NaN            2          2         2
#
# [7 rows x 29 columns]

# %%
import sys
import numpy as np

# Assuming nqm and sqm are defined earlier in your notebook
# Define your function here
def your_function():
    print('1-Most Number of Discrepancies found in districts-',x,'\n\n',
      '2-Least Number of NQM inspection-',x1,'\n\n',
      '3-Least Number of SQM inspection-',x2,'\n\n',
      '4-Number Of Discrepancies in last 5 years-',x3,'\n\n',
      '5-Number Of Discrepancies Levelwise-',x4,'\n\n\n\n',
      'NOTE- 1-All The Results are based On a Deep Learning Model of 99.91% Accuracy','\n',
      '2-Discrepancies are Found on the basis of comparison between NQM and SQM')
with open('output.txt', 'w') as f:
    original_stdout = sys.stdout
    sys.stdout = f
    your_function()
    sys.stdout = original_stdout

# %%
sqm
# Out:
#    State(SQM) Sanction Year  SQM I.C.       SQM_Grade  Status(SQM)  \
# 0  Tamil Nadu     2015-2016        11    satisfactory  In Progress
# 1  Tamil Nadu     2016-2017         7    satisfactory  Maintenance
# 2  Tamil Nadu     2015-2016         2    satisfactory  In Progress
# 3  Tamil Nadu     2015-2016         6    satisfactory  Maintenance
# 4  Tamil Nadu     2014-2015         5    satisfactory  Maintenance
# 5  Tamil Nadu     2016-2017         7    satisfactory  Maintenance
# 6  Tamil Nadu     2014-2015         4  Unsatisfactory  Maintenance
#
#    Road_Length(SQM)  District        Block  \
# 0             5.400  Ariyalur    Andimadam
# 1             5.520  Ariyalur     Ariyalur
# 2             1.325  Ariyalur     Ariyalur
# 3             1.250  Ariyalur     Ariyalur
# 4             1.125  Ariyalur     Ariyalur
# 5             1.000  Ariyalur  Jayamkondam
# 6             3.000  Ariyalur  Jayamkondam
#
#                                            Road_name     Monitor Name(SQM)  \
# 0          L060-Silambur to Thirukonam road (VR2180)  Durairaj Kumaraswamy
# 1                        poyyathanallur - illupaiyur           C Duraisamy
# 2           L073-AS road to Ameenabath road (VR2041)          Y CHRISTDHAS
# 3           L063-AA road to Kayarlabad road (VR2066)   Thiruppathy Chithan
# 4  L047-Karuppur Poiyyur - Oriyur - Nanangur road...     Muthuvalliappan M
# 5                           Meensurity - Kuttakkarai           Thangaraj D
# 6  \t\nMRL12-Meikavalputhur-Veeracholapuram (via)...     Muthuvalliappan M
#
#    ... Base Course-Water Bound Macadam(SQM) Unnamed: 18  Unnamed: 19  \
# 0  ...                                    2         NaN          NaN
# 1  ...                                    2         NaN          NaN
# 2  ...                                    1         NaN          NaN
# 3  ...                                    1         NaN          NaN
# 4  ...                                    1         NaN          NaN
# 5  ...                                    2         NaN          NaN
# 6  ...                                    1         NaN          NaN
#
#    Cross Drainage Works(SQM)  Unnamed: 21  Road Furnitures And Markings(SQM)  \
# 0                          2          NaN                                  1
# 1                          2          NaN                                  2
# 2                          2          NaN                                  1
# 3                          2          NaN                                  1
# 4                          2          NaN                                  1
# 5                          2          NaN                                  2
# 6                          2          NaN                                  1
#
#    Unnamed: 23  Maintenance(SQM)  Shoulders(SQM)  pavement(SQM)
# 0          NaN                 2               2              2
# 1          NaN                 1               1              1
# 2          NaN                 2               2              2
# 3          NaN                 2               1              2
# 4          NaN                 2               1              2
# 5          NaN                 1               1              1
# 6          NaN                 2               2              2
#
# [7 rows x 27 columns]

# %%
from fpdf import FPDF

class PDF(FPDF):
    def add_title(self, title):
        self.set_font('Arial', 'B', 12)
        self.cell(0, 10, title, 0, 1, 'C')

    def add_text(self, file):
        with open(file, 'r', encoding='utf-8') as file:
            for line in file:
                self.set_font('Arial', '', 12)
                self.multi_cell(0, 10, line)

# Create a PDF object
pdf = PDF()
pdf.add_page()

# Add a title
pdf.add_title('Surface Report')

# Add text from the file
pdf.add_text('output.txt')

# Save the PDF
pdf.output("Surface_Report.pdf")
# Out:
# ''

# %%
nqm.dropna(axis='columns',inplace=True)

# %%
sqm.dropna(axis='columns',inplace=True)

# %%
 print('***************** DETAILED REPORT *********************\n\n')
for i in range(nqm.District.count()):
    print('DISCREPANCY',i,':\n','STATE:',nqm.State[i],'\n','DISTRICT:',nqm.District[i],'\n',
         'BLOCK:',nqm.Block[i],'\n\n','SANCTION YEAR:',nqm['Sanction Year'][i],'\n','PACKAGE NUMBER:',nqm.Package[i],'\n',
         'ROAD NAME :',nqm.Road_name[i],'\n','ROAD LENGTH:',nqm.Road_Length[i],'\n\n',
         'NQM Inspection count:',nqm['NQM I.C.'][i],'\n','NQM Grading:',nqm.NQM_Grade[i],'\n','NQM Name:',
          nqm['Monitor Name'][i],'\n','NQM Inspection date:',
          nqm['Inspection Date'][i],'\n','Status:',nqm.Status[i],'\n','Start Chainage:',
          nqm['Start Chainage'][i],'\n','End Chainage:',nqm['End Chainage'][i],'\n\n',
          'SQM Inspection count:',sqm['SQM I.C.'][i],'\n','SQM Grading:',sqm.SQM_Grade[i],'\n','SQM Name:',
          sqm['Monitor Name(SQM)'][i],'\n','SQM Inspection date:',
          sqm['Inspection Date(SQM)'][i],'\n','Status:',sqm['Status(SQM)'][i],'\n','Start Chainage:',
          sqm['Start Chainage(SQM)'][i],'\n','End Chainage:',sqm['End Chainage(SQM)'][i],'\n\n'
          'Discrepancy item(s):',np.where(nqm['Quality Arrangment'][i]!=sqm['Quality Arrangment(SQM)'][i],'Quality Arrangment',''),' ',
          np.where(nqm['Attention To Quality'][i]!=sqm['Attention To Quality(SQM)'][i],'Attention To Quality',''),' ',
         np.where(nqm['Geometrics'][i]!=sqm['Geometrics(SQM)'][i],'Geometrics',''),' ',
         np.where(nqm['Base Course-Water Bound Macadam'][i]!=sqm['Base Course-Water Bound Macadam(SQM)'][i],'Base Course-Water Bound Macadam',''),' ',
         np.where(nqm['Cross Drainage Works'][i]!=sqm['Cross Drainage Works(SQM)'][i],'Cross Drainage Works',''),' ',
         np.where(nqm['Road Furnitures And Markings'][i]!=sqm['Road Furnitures And Markings(SQM)'][i],'Road Furnitures And Markings',''),' ',
         np.where(nqm['Maintenance'][i]!=sqm['Maintenance(SQM)'][i],'Maintenance',''),' ', 
         np.where(nqm['Shoulders'][i]!=sqm['Shoulders(SQM)'][i],'Shoulders',''),' ', 
         	np.where(nqm['pavement'][i]!=sqm['pavement(SQM)'][i],'pavement',''),' ')
# Out:
# ***************** DETAILED REPORT *********************
#
#
# DISCREPANCY 0 :
#  STATE: Tamil Nadu
#  DISTRICT: Ariyalur
#  BLOCK: Andimadam
#
#  SANCTION YEAR: 2015-2016
#  PACKAGE NUMBER: TN3090
#  ROAD NAME : L060-Silambur to Thirukonam road (VR2180)
#  ROAD LENGTH: 5.4
#
#  NQM Inspection count: 1
#  NQM Grading: Unsatisfactory
#  NQM Name: Dange Pradeep Bhaskar rao
#  NQM Inspection date: 24-09-2016
#  Status: In Progress
#  Start Chainage: 1
#  End Chainage: 4.0
#
#  SQM Inspection count: 11
#  SQM Grading: satisfactory
#  SQM Name: Durairaj Kumaraswamy
#  SQM Inspection date: 23-02-2016
#  Status: In Progress
#  Start Chainage: 0
#  End Chainage: 5.4
#
# Discrepancy item(s):       Geometrics   Base Course-Water Bound Macadam   Cross Drainage Works
# DISCREPANCY 1 :
#  STATE: Tamil Nadu
#  DISTRICT: Ariyalur
#  BLOCK: Ariyalur
#
#  SANCTION YEAR: 2016-2017
#  PACKAGE NUMBER: TN1165
#  ROAD NAME : poyyathanallur - illupaiyur
#  ROAD LENGTH: 5.52
#
#  NQM Inspection count: 2
#  NQM Grading: Unsatisfactory
#  NQM Name: Sharma Deputy Lal
#  NQM Inspection date: 26-08-2018
#  Status: Maintenance
#  Start Chainage: 0
#  End Chainage: 5.5
#
#  SQM Inspection count: 7
#  SQM Grading: satisfactory
#  SQM Name: C Duraisamy
#  SQM Inspection date: 17-02-2018
#  Status: Maintenance
#  Start Chainage: 0
#  End Chainage: 5.5
#
# Discrepancy item(s):                   Maintenance   Shoulders
# DISCREPANCY 2 :
#  STATE: Tamil Nadu
#  DISTRICT: Ariyalur
#  BLOCK: Ariyalur
#
#  SANCTION YEAR: 2015-2016
#  PACKAGE NUMBER: TN3082
#  ROAD NAME : L073-AS road to Ameenabath road (VR2041)
#  ROAD LENGTH: 1.325
#
#  NQM Inspection count: 1
#  NQM Grading: Unsatisfactory
#  NQM Name: Dange Pradeep Bhaskar rao
#  NQM Inspection date: 23-09-2016
#  Status: In Progress
#  Start Chainage: 0
#  End Chainage: 1.325
#
#  SQM Inspection count: 2
#  SQM Grading: satisfactory
#  SQM Name: Y CHRISTDHAS
#  SQM Inspection date: 24-08-2016
#  Status: In Progress
#  Start Chainage: 0
#  End Chainage: 1.325
#
# Discrepancy item(s):          Base Course-Water Bound Macadam   Cross Drainage Works
# DISCREPANCY 3 :
#  STATE: Tamil Nadu
#  DISTRICT: Ariyalur
#  BLOCK: Ariyalur
#
#  SANCTION YEAR: 2015-2016
#  PACKAGE NUMBER: TN3083
#  ROAD NAME : L063-AA road to Kayarlabad road (VR2066)
#  ROAD LENGTH: 1.25
#
#  NQM Inspection count: 1
#  NQM Grading: Unsatisfactory
#  NQM Name: Suresh Chandra Sharma
#  NQM Inspection date: 14-12-2018
#  Status: Maintenance
#  Start Chainage: 0
#  End Chainage: 1.25
#
#  SQM Inspection count: 6
#  SQM Grading: satisfactory
#  SQM Name: Thiruppathy Chithan
#  SQM Inspection date: 29-08-2017
#  Status: Maintenance
#  Start Chainage: 0
#  End Chainage: 1.25
#
# Discrepancy item(s):       Geometrics   Base Course-Water Bound Macadam      Road Furnitures And Markings   Maintenance   Shoulders   pavement
# DISCREPANCY 4 :
#  STATE: Tamil Nadu
#  DISTRICT: Ariyalur
#  BLOCK: Ariyalur
#
#  SANCTION YEAR: 2014-2015
#  PACKAGE NUMBER: TN3086
#  ROAD NAME : L047-Karuppur Poiyyur - Oriyur - Nanangur road to Puthur road (VR2067)
#  ROAD LENGTH: 1.125
#
#  NQM Inspection count: 1
#  NQM Grading: Unsatisfactory
#  NQM Name: Suresh Chandra Sharma
#  NQM Inspection date: 14-12-2018
#  Status: Maintenance
#  Start Chainage: 0
#  End Chainage: 1.125
#
#  SQM Inspection count: 5
#  SQM Grading: satisfactory
#  SQM Name: Muthuvalliappan M
#  SQM Inspection date: 22-02-2017
#  Status: Maintenance
#  Start Chainage: 0
#  End Chainage: 1.125
#
# Discrepancy item(s):       Geometrics   Base Course-Water Bound Macadam      Road Furnitures And Markings   Maintenance   Shoulders   pavement
# DISCREPANCY 5 :
#  STATE: Tamil Nadu
#  DISTRICT: Ariyalur
#  BLOCK: Jayamkondam
#
#  SANCTION YEAR: 2016-2017
#  PACKAGE NUMBER: TN1166
#  ROAD NAME : Meensurity - Kuttakkarai
#  ROAD LENGTH: 1.0
#
#  NQM Inspection count: 2
#  NQM Grading: Unsatisfactory
#  NQM Name: Sharma Deputy Lal
#  NQM Inspection date: 26-04-2018
#  Status: Maintenance
#  Start Chainage: 0
#  End Chainage: 1.0
#
#  SQM Inspection count: 7
#  SQM Grading: satisfactory
#  SQM Name: Thangaraj D
#  SQM Inspection date: 25-11-2017
#  Status: Maintenance
#  Start Chainage: 0
#  End Chainage: 1.0
#
# Discrepancy item(s):                      Shoulders
# DISCREPANCY 6 :
#  STATE: Tamil Nadu
#  DISTRICT: Ariyalur
#  BLOCK: Jayamkondam
#
#  SANCTION YEAR: 2014-2015
#  PACKAGE NUMBER: TN30105
#  ROAD NAME :
# MRL12-Meikavalputhur-Veeracholapuram (via) Mendevanallur road
#  ROAD LENGTH: 3.0
#
#  NQM Inspection count: 1
#  NQM Grading: Satisfactory
#  NQM Name: Prakash Anugrah
#  NQM Inspection date: 16-09-2018
#  Status: Maintenance
#  Start Chainage: 0
#  End Chainage: 3.0
#
#  SQM Inspection count: 4
#  SQM Grading: Unsatisfactory
#  SQM Name: Muthuvalliappan M
#  SQM Inspection date: 11-08-2018
#  Status: Maintenance
#  Start Chainage: 0
#  End Chainage: 3.0
#
# Discrepancy item(s):          Base Course-Water Bound Macadam

# %%
import sys
import numpy as np

# Assuming nqm and sqm are defined earlier in your notebook
# Define your function here
def your_function():
    for i in range(nqm.District.count()):
        print('DISCREPANCY',i,':\n','STATE:',nqm.State[i],'\n','DISTRICT:',nqm.District[i],'\n',
         'BLOCK:',nqm.Block[i],'\n\n','SANCTION YEAR:',nqm['Sanction Year'][i],'\n','PACKAGE NUMBER:',nqm.Package[i],'\n',
         'ROAD NAME :',nqm.Road_name[i],'\n','ROAD LENGTH:',nqm.Road_Length[i],'\n\n',
         'NQM Inspection count:',nqm['NQM I.C.'][i],'\n','NQM Grading:',nqm.NQM_Grade[i],'\n','NQM Name:',
          nqm['Monitor Name'][i],'\n','NQM Inspection date:',
          nqm['Inspection Date'][i],'\n','Status:',nqm.Status[i],'\n','Start Chainage:',
          nqm['Start Chainage'][i],'\n','End Chainage:',nqm['End Chainage'][i],'\n\n',
          'SQM Inspection count:',sqm['SQM I.C.'][i],'\n','SQM Grading:',sqm.SQM_Grade[i],'\n','SQM Name:',
          sqm['Monitor Name(SQM)'][i],'\n','SQM Inspection date:',
          sqm['Inspection Date(SQM)'][i],'\n','Status:',sqm['Status(SQM)'][i],'\n','Start Chainage:',
          sqm['Start Chainage(SQM)'][i],'\n','End Chainage:',sqm['End Chainage(SQM)'][i],'\n\n'
          'Discrepancy item(s):',np.where(nqm['Quality Arrangment'][i]!=sqm['Quality Arrangment(SQM)'][i],'Quality Arrangment',''),' ',
          np.where(nqm['Attention To Quality'][i]!=sqm['Attention To Quality(SQM)'][i],'Attention To Quality',''),' ',
         np.where(nqm['Geometrics'][i]!=sqm['Geometrics(SQM)'][i],'Geometrics',''),' ',
         np.where(nqm['Base Course-Water Bound Macadam'][i]!=sqm['Base Course-Water Bound Macadam(SQM)'][i],'Base Course-Water Bound Macadam',''),' ',
         np.where(nqm['Cross Drainage Works'][i]!=sqm['Cross Drainage Works(SQM)'][i],'Cross Drainage Works',''),' ',
         np.where(nqm['Road Furnitures And Markings'][i]!=sqm['Road Furnitures And Markings(SQM)'][i],'Road Furnitures And Markings',''),' ',
         np.where(nqm['Maintenance'][i]!=sqm['Maintenance(SQM)'][i],'Maintenance',''),' ', 
         np.where(nqm['Shoulders'][i]!=sqm['Shoulders(SQM)'][i],'Shoulders',''),' ', 
         	np.where(nqm['pavement'][i]!=sqm['pavement(SQM)'][i],'pavement',''),' ')
        

# Redirecting output to a file
with open('output.txt', 'w') as f:
    original_stdout = sys.stdout
    sys.stdout = f
    your_function()
    sys.stdout = original_stdout

# %%
from fpdf import FPDF

class PDF(FPDF):
    def add_title(self, title):
        self.set_font('Arial', 'B', 12)
        self.cell(0, 10, title, 0, 1, 'C')

    def add_text(self, file):
        with open(file, 'r', encoding='utf-8') as file:
            for line in file:
                self.set_font('Arial', '', 12)
                self.multi_cell(0, 10, line)

# Create a PDF object
pdf = PDF()
pdf.add_page()

# Add a title
pdf.add_title('Detailed Report')

# Add text from the file
pdf.add_text('output.txt')

# Save the PDF
pdf.output("Detailed_Report.pdf")
# Out:
# ''

# %%
import aspose.words as aw

doc = aw.Document("Detailed_Report.pdf")
doc.save("Detailed_Report.docx")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/mohitverma/Desktop/projects/SIH23/MLmodel/Data Cleaning OMMAS-4 3.ipynb Cell 49 line 3
#       <a href='vscode-notebook-cell:/Users/mohitverma/Desktop/projects/SIH23/MLmodel/Data%20Cleaning%20OMMAS-4%203.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> import aspose.words as aw
# ----> <a href='vscode-notebook-cell:/Users/mohitverma/Desktop/projects/SIH23/MLmodel/Data%20Cleaning%20OMMAS-4%203.ipynb#X66sZmlsZQ%3D%3D?line=2'>3</a> doc = aw.Document("Detailed_Report.pdf")
#       <a href='vscode-notebook-cell:/Users/mohitverma/Desktop/projects/SIH23/MLmodel/Data%20Cleaning%20OMMAS-4%203.ipynb#X66sZmlsZQ%3D%3D?line=3'>4</a> doc.save("Detailed_Report.docx")
#
# RuntimeError: Proxy error(FileNotFoundException): Could not find file '/Users/mohitverma/Desktop/projects/SIH23/MLmodel/Detailed_Report.pdf'.

# %%
import pandas as pd
from docx import Document
from textblob import TextBlob  # Assuming you're using TextBlob for sentiment analysis

# Load the Word document
doc_path = 'Detailed_Report.docx'
doc = Document(doc_path)

# Extract text from paragraphs in the document
text_content = [paragraph.text for paragraph in doc.paragraphs]

# Create a DataFrame for the text data
data = pd.DataFrame({'text': text_content})

# %%
print(text_content)
# Out:
# ['Evaluation Only. Created with Aspose.Words. Copyright 2003-2023 Aspose Pty Ltd.', 'Detailed Report', 'DISCREPANCY 0 :', ' STATE: Tamil Nadu  DISTRICT: Ariyalur ', ' BLOCK: Andimadam ', ' SANCTION YEAR: 2015-2016 ', ' PACKAGE NUMBER: TN3090 ', ' ROAD NAME : L060-Silambur to Thirukonam road (VR2180)  ROAD LENGTH: 5.4 ', ' NQM Inspection count: 1 ', ' NQM Grading: Unsatisfactory ', ' NQM Name: Dange Pradeep Bhaskar rao  NQM Inspection date: 24-09-2016 ', ' Status: In Progress ', ' Start Chainage: 1 ', ' End Chainage: 4.0 ', ' SQM Inspection count: 11 ', ' SQM Grading: satisfactory ', ' SQM Name: Durairaj Kumaraswamy  SQM Inspection date: 23-02-2016 ', ' Status: In Progress ', ' Start Chainage: 0 ', ' End Chainage: 5.4 ', 'Discrepancy item(s):       Geometrics   Base Course-Water Bound Macadam   Cross Drainage Works              ', 'DISCREPANCY 1 :', ' STATE: Tamil Nadu ', ' DISTRICT: Ariyalur ', ' BLOCK: Ariyalur ', ' SANCTION YEAR: 2016-2017 ', ' PACKAGE NUMBER: TN1165 ', ' ROAD NAME : poyyathanallur - illupaiyur  ROAD LENGTH: 5.52 ', ' NQM Inspection count: 2 ', ' NQM Grading: Unsatisfactory ', ' NQM Name: Sharma Deputy Lal  NQM Inspection date: 26-08-2018  Status: Maintenance ', ' Start Chainage: 0 ', ' End Chainage: 5.5 ', ' SQM Inspection count: 7 ', ' SQM Grading: satisfactory ', ' SQM Name: C Duraisamy ', ' SQM Inspection date: 17-02-2018  Status: Maintenance ', ' Start Chainage: 0  End Chainage: 5.5 ', 'Discrepancy item(s):                   Maintenance   Shoulders     DISCREPANCY 2 :', ' STATE: Tamil Nadu ', ' DISTRICT: Ariyalur ', ' BLOCK: Ariyalur ', ' SANCTION YEAR: 2015-2016 ', ' PACKAGE NUMBER: TN3082 ', ' ROAD NAME : L073-AS road to Ameenabath road (VR2041)  ROAD LENGTH: 1.325 ', ' NQM Inspection count: 1 ', ' NQM Grading: Unsatisfactory ', ' NQM Name: Dange Pradeep Bhaskar rao  NQM Inspection date: 23-09-2016 ', ' Status: In Progress ', ' Start Chainage: 0 ', ' End Chainage: 1.325 ', ' SQM Inspection count: 2 ', ' SQM Grading: satisfactory ', ' SQM Name: Y CHRISTDHAS ', ' SQM Inspection date: 24-08-2016 ', ' Status: In Progress ', ' Start Chainage: 0 ', ' End Chainage: 1.325 ', 'Discrepancy item(s):          Base Course-Water Bound Macadam   Cross Drainage Works              DISCREPANCY 3 :', ' STATE: Tamil Nadu ', ' DISTRICT: Ariyalur ', ' BLOCK: Ariyalur ', ' SANCTION YEAR: 2015-2016 ', ' PACKAGE NUMBER: TN3083 ', ' ROAD NAME : L063-AA road to Kayarlabad road (VR2066)  ROAD LENGTH: 1.25 ', ' NQM Inspection count: 1 ', ' NQM Grading: Unsatisfactory ', ' NQM Name: Suresh Chandra Sharma  NQM Inspection date: 14-12-2018 ', ' Status: Maintenance ', ' Start Chainage: 0 ', ' End Chainage: 1.25 ', ' SQM Inspection count: 6 ', ' SQM Grading: satisfactory ', ' SQM Name: Thiruppathy Chithan ', ' SQM Inspection date: 29-08-2017  Status: Maintenance ', ' Start Chainage: 0 ', ' End Chainage: 1.25 ', 'Discrepancy item(s):       Geometrics   Base Course-Water Bound Macadam      Road Furnitures And Markings   Maintenance   Shoulders   pavement  ', 'DISCREPANCY 4 :', ' STATE: Tamil Nadu ', ' DISTRICT: Ariyalur ', ' BLOCK: Ariyalur ', ' SANCTION YEAR: 2014-2015 ', ' PACKAGE NUMBER: TN3086 ', ' ROAD NAME : L047-Karuppur Poiyyur - Oriyur - Nanangur road to Puthur road (VR2067)  ROAD LENGTH: 1.125 ', ' NQM Inspection count: 1 ', ' NQM Grading: Unsatisfactory ', ' NQM Name: Suresh Chandra Sharma  NQM Inspection date: 14-12-2018 ', ' Status: Maintenance ', ' Start Chainage: 0 ', ' End Chainage: 1.125 ', ' SQM Inspection count: 5 ', ' SQM Grading: satisfactory ', ' SQM Name: Muthuvalliappan M ', ' SQM Inspection date: 22-02-2017  Status: Maintenance ', ' Start Chainage: 0 ', ' End Chainage: 1.125 ', 'Discrepancy item(s):       Geometrics   Base Course-Water Bound Macadam      Road Furnitures And Markings   Maintenance   Shoulders   pavement  ', 'DISCREPANCY 5 :', ' STATE: Tamil Nadu ', ' DISTRICT: Ariyalur ', ' BLOCK: Jayamkondam ', ' SANCTION YEAR: 2016-2017 ', ' PACKAGE NUMBER: TN1166 ', ' ROAD NAME : Meensurity - Kuttakkarai  ROAD  ...

# %%
print(data)
# Out:
#                                                   text
# 0    Evaluation Only. Created with Aspose.Words. Co...
# 1                                      Detailed Report
# 2                                      DISCREPANCY 0 :
# 3               STATE: Tamil Nadu  DISTRICT: Ariyalur
# 4                                    BLOCK: Andimadam
# ..                                                 ...
# 131                       SQM Name: Muthuvalliappan M
# 132   SQM Inspection date: 11-08-2018  Status: Main...
# 133                                 Start Chainage: 0
# 134                                 End Chainage: 3.0
# 135  Discrepancy item(s):          Base Course-Wate...
#
# [136 rows x 1 columns]

# %%
# Sample text containing discrepancies and corrective measures
text_report = """
1._Maintenance of Road :

Rain Cuts: Restore using proper backfilling and compaction. Use geotextiles if necessary for stabilization.
Vegetation: Regularly trim branches, shrubs, and grass. Ensure clear visibility for road users and prevent obstruction of traffic signs.

2._Making up of Earthen Shoulders:

Ensure proper grading and compaction to match the road level. Regular maintenance is needed to prevent erosion.

3._Condition of Pavement :

Potholes: Fill with appropriate materials (asphalt or concrete) followed by compaction.
Patch Repairs: Use a cut-and-patch method for larger areas, ensuring the patch is well integrated with the existing pavement.

4._Road Furniture and Markings:

Regularly repaint road markings.
Maintain visibility and positioning of road furniture.

5._Geometrics:

Regularly assess and maintain road alignment, curvature, and gradients to meet design standards.

6._Base Course - Water Bound Macadam (WBM):

Regularly inspect for surface evenness, and presence of potholes or ruts.
For repairs, remove the loose material, re-grade and re-compact the area.

7._Cross drainage works:

Regular cleaning to prevent blockages.
Structural inspection and repair of any damages to maintain functionality.
In case of significant damage, reconstruct the affected area with fresh WBM layers, ensuring proper gradation of aggregates and adequate binding with stone dust or fine aggregates.
Ensure proper water drainage to avoid water logging which can weaken the WBM structure.

... (more discrepancies and corrective measures)
"""
import re
# Split the text into individual discrepancies and corrective measures
discrepancies_and_measures = re.split(r'\d+\..', text_report)
discrepancies_and_measures = [d.strip() for d in discrepancies_and_measures if d.strip()]

# Function to clean up and format text
def clean_text(text):
    # Remove extra whitespace and leading/trailing newlines
    return ' '.join(text.split())

# Create a dictionary to store discrepancies and their associated corrective measures
discrepancy_to_measure = {}

# Extract discrepancies and their respective measures
for idx, item in enumerate(discrepancies_and_measures):
    item = clean_text(item)
    discrepancy_and_measure = item.split(':', 1)
    if len(discrepancy_and_measure) == 2:
        discrepancy, measure = discrepancy_and_measure
        discrepancy_to_measure[discrepancy.strip()] = measure.strip()

# Print discrepancies and their associated corrective measures
for discrepancy, measure in discrepancy_to_measure.items():
    print(f"Discrepancy: {discrepancy}")
    print(f"Corrective Measure: {measure}\n")
# Out:
# Discrepancy: Maintenance of Road
# Corrective Measure: Rain Cuts: Restore using proper backfilling and compaction. Use geotextiles if necessary for stabilization. Vegetation: Regularly trim branches, shrubs, and grass. Ensure clear visibility for road users and prevent obstruction of traffic signs.
#
# Discrepancy: Making up of Earthen Shoulders
# Corrective Measure: Ensure proper grading and compaction to match the road level. Regular maintenance is needed to prevent erosion.
#
# Discrepancy: Condition of Pavement
# Corrective Measure: Potholes: Fill with appropriate materials (asphalt or concrete) followed by compaction. Patch Repairs: Use a cut-and-patch method for larger areas, ensuring the patch is well integrated with the existing pavement.
#
# Discrepancy: Road Furniture and Markings
# Corrective Measure: Regularly repaint road markings. Maintain visibility and positioning of road furniture.
#
# Discrepancy: Geometrics
# Corrective Measure: Regularly assess and maintain road alignment, curvature, and gradients to meet design standards.
#
# Discrepancy: Base Course - Water Bound Macadam (WBM)
# Corrective Measure: Regularly inspect for surface evenness, and presence of potholes or ruts. For repairs, remove the loose material, re-grade and re-compact the area.
#
# Discrepancy: Cross drainage works
# Corrective Measure: Regular cleaning to prevent blockages. Structural inspection and repair of any damages to maintain functionality. In case of significant damage, reconstruct the affected area with fresh WBM layers, ensuring proper gradation of aggregates and adequate binding with stone dust or fine aggregates. Ensure proper water drainage to avoid water logging which can weaken the WBM structure. ... (more discrepancies and corrective measures)

# %%
import sys
import re

def process_text_report(text_report):
    # Split the text into individual items
    items = re.split(r'\d+\..', text_report)
    items = [item.strip() for item in items if item.strip()]

    # Create and return a dictionary of discrepancies and measures
    discrepancy_to_measure = {}
    for item in items:
        item = ' '.join(item.split())  # Clean up the text
        discrepancy_and_measure = item.split(':', 1)
        if len(discrepancy_and_measure) == 2:
            discrepancy, measure = discrepancy_and_measure
            discrepancy_to_measure[discrepancy.strip()] = measure.strip()
    return discrepancy_to_measure

def write_to_file(discrepancy_to_measure, filename='output.txt'):
    with open(filename, 'w') as f:
        for discrepancy, measure in discrepancy_to_measure.items():
            print(f"Discrepancy: {discrepancy}", file=f)
            print(f"Corrective Measure: {measure}\n", file=f)

# Your text report
text_report = """
1._Maintenance of Road :

Rain Cuts: Restore using proper backfilling and compaction. Use geotextiles if necessary for stabilization.
Vegetation: Regularly trim branches, shrubs, and grass. Ensure clear visibility for road users and prevent obstruction of traffic signs.

2._Making up of Earthen Shoulders:

Ensure proper grading and compaction to match the road level. Regular maintenance is needed to prevent erosion.

3._Condition of Pavement :

Potholes: Fill with appropriate materials (asphalt or concrete) followed by compaction.
Patch Repairs: Use a cut-and-patch method for larger areas, ensuring the patch is well integrated with the existing pavement.

4._Road Furniture and Markings:

Regularly repaint road markings.
Maintain visibility and positioning of road furniture.

5._Geometrics:

Regularly assess and maintain road alignment, curvature, and gradients to meet design standards.

6._Base Course - Water Bound Macadam (WBM):

Regularly inspect for surface evenness, and presence of potholes or ruts.
For repairs, remove the loose material, re-grade and re-compact the area.

7._Cross drainage works:

Regular cleaning to prevent blockages.
Structural inspection and repair of any damages to maintain functionality.
In case of significant damage, reconstruct the affected area with fresh WBM layers, ensuring proper gradation of aggregates and adequate binding with stone dust or fine aggregates.
Ensure proper water drainage to avoid water logging which can weaken the WBM structure.

... (more discrepancies and corrective measures)
"""

# Process the text report and write the output to a file
discrepancy_to_measure = process_text_report(text_report)
write_to_file(discrepancy_to_measure)

# %%
from fpdf import FPDF

class PDF(FPDF):
    def add_title(self, title):
        self.set_font('Arial', 'B', 12)
        self.cell(0, 10, title, 0, 1, 'C')

    def add_text(self, file):
        with open(file, 'r', encoding='utf-8') as file:
            for line in file:
                self.set_font('Arial', '', 12)
                self.multi_cell(0, 10, line)

# Create a PDF object
pdf = PDF()
pdf.add_page()

# Add a title
pdf.add_title('Corrective Measure')

# Add text from the file
pdf.add_text('output.txt')

# Save the PDF
pdf.output("Corrective Measures.pdf")
# Out:
# ''

# %%
import PyPDF2

pdfFiles = ['Surface_Report.pdf', 'Detailed_Report.pdf', 'Corrective Measures.pdf']  # List of PDF filenames
pdfWriter = PyPDF2.PdfWriter()

for filename in pdfFiles:
    with open(filename, 'rb') as pdfFileObj:
        pdfReader = PyPDF2.PdfReader(pdfFileObj)
        
        # Example: Adding all pages from each PDF
        for pageNum in range(len(pdfReader.pages)):
            pageObj = pdfReader.pages[pageNum]
            pdfWriter.add_page(pageObj)

# Write to a new PDF file
with open('Report.pdf', 'wb') as outputFile:
    pdfWriter.write(outputFile)

# %%
import PyPDF2

# List of PDF filenames
pdfFiles = ['Surface_Report.pdf', 'Detailed_Report.pdf', 'Corrective Measures.pdf']
pdfWriter = PyPDF2.PdfWriter()

# Assuming the PDF files are in the current working directory, add them to the writer
for filename in pdfFiles:
    with open(filename, 'rb') as pdfFileObj:
        pdfReader = PyPDF2.PdfReader(pdfFileObj)
        
        # Add all pages from each PDF
        for pageNum in range(len(pdfReader.pages)):
            pageObj = pdfReader.pages[pageNum]
            pdfWriter.add_page(pageObj)

# Path where the merged PDF will be stored
outputFilePath = '/Users/mohitverma/Desktop/projects/SIH23/DetailedReports/Report.pdf'

# Write to the new PDF file in the specified directory
with open(outputFilePath, 'wb') as outputFile:
    pdfWriter.write(outputFile)
